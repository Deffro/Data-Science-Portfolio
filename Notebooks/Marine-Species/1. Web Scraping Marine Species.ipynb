# %%
import re
import numpy as np
import pandas as pd
import requests
import bs4
from bs4 import BeautifulSoup 

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1500)
pd.set_option('max_colwidth', 100)

# %%
# Create the DataFrame that will store everythin in the end
dataset = pd.DataFrame(columns=['scientificName','commonName','classification','etymology','environment','depthRange',
                               'usualRange','distributionRangeName','distributionRangeCoordinates','distributionDescription',
                               'sizeRange','maxLength','commonLength','maxWeight','maxAge','biologyInfo','lifeAndMateInfo',
                               'redListStatus','dorsalSpines','dorsalSoftRays','analSpines','analSoftRays','vertebrae',
                               'shortDescription','threatToHumans','preferredTemperatureMin','preferredTemperatureMean',
                               'preferredTemperatureMax','cellsBasedOn','phylogeneticDiversity','bayesianLengthWeightA',
                                'bayesianLengthWeightB','resilience','priorR','sdRange','vulnerability','priceCategory','source'])

speciesList = pd.read_csv('../speciesList.csv') # Catalog of Mediterranean Species
for i, row in speciesList.iterrows():
    species = row['Species'].replace(' ', '-')
    
    # Collect page
    page_de = requests.get('https://www.fishbase.de/summary/'+species+'.html')
    page_ca = requests.get('https://www.sealifebase.ca/summary/'+species+'.html')
    
    # Create a BeautifulSoup object
    soup_de = BeautifulSoup(page_de.text, 'html.parser')
    soup_ca = BeautifulSoup(page_ca.text, 'html.parser')

    if ('Species name is not in the public version of FishBase.' not in str(soup_de)):
        print('Using www.fishbase.de for\t:',row['Species'])
        website = 'de'
        soup = soup_de
    elif ('Species name is not in the public version of SeaLifeBase.' not in str(soup_ca)):
        print('Using www.sealifebase.ca for\t:',row['Species'])
        website = 'ca'
        soup = soup_ca
    else:
        print(row['Species'], 'species not existing in any of www.fishbase.de and www.sealifebase.ca')
        website = 'non'
    
    if (website=='de'):  

        # Initialize every final variable to nan
        commonName, classification, etymology, environment, depthRange, usualRange, distributionRangeName, distributionRangeCoordinates, distributionDescription = np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan
        sizeRange, maxLength, commonLength, maxWeight, maxAge, biologyInfo, lifeAndMateInfo, redListStatus = np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan
        dorsalSpines, dorsalSoftRays, analSpines, analSoftRays, vertebrae, shortDescription, threatToHumans, preferredTemperatureMin, preferredTemperatureMean, preferredTemperatureMax, cellsBasedOn = np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan
        phylogeneticDiversity, bayesianLengthWeightA, bayesianLengthWeightB, resilience, priorR, sdRange, vulnerability, priceCategory = np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan


        # Scientific name and Common Name
        scientificName = ''
        divScientificName = soup.find(id='ss-sciname') # Find a specific id in html
        divScientificNameUrls = divScientificName.find_all('a') # Find all specific tags and return a list
        for name in divScientificNameUrls: # Loop because name is in one or more <a> tags
            scientificName += name.contents[0]+" " # Contents gets the text of the beautifulsoup element
        scientificName = scientificName.rstrip() # Remove all whitespaces at the end of string

        # Collect common name
        commonName = soup.find(class_='sheader2').contents[0]
        commonName = re.sub(r"[\n\t\r]*", "", commonName) # Remove new lines and tabs if exist
        if (commonName == ''):
            commonName = np.nan    



        # Get fields and headers to use later
        divMain = soup.find(id='ss-main')
        fields = divMain.find_all(class_='smallSpace') # Here is all the content we need
        fieldHeaders = divMain.find_all('h1') # Store the headers because not all of them are always present

        classificationField, environmentField, distributionField, metricsField, shortDescriptionField, biologyField, lifeAndMateField, redListStatusField, threatToHumansField, humanUsesField, estimatesPropertiesField = False, False, False, False, False, False, False, False, False, False, False   
        for i, header in enumerate(fieldHeaders):
            fieldHeader = header.get_text()
            fieldHeader = re.sub(r"[\n\t\r]*", "", fieldHeader)

            # Each header has always the strings specified in the if statements. If such a string does not exist, then the header and the content are missing
            if ('Classification / Names' in fieldHeader):
                classificationField = fields[i]
            if ('Environment: milieu' in fieldHeader):
                environmentField = fields[i]
                environmentField = environmentField.find('span').contents
            if ('Distribution' in fieldHeader):
                distributionField = fields[i]
                distributionField = distributionField.find('span').contents
            if ('Size' in fieldHeader):
                metricsField = fields[i]
                metricsField = metricsField.find('span').contents
            if ('Short description' in fieldHeader):
                shortDescriptionField = fields[i]
                shortDescriptionField = shortDescriptionField.find('span').contents
            if ('Biology' in fieldHeader):
                biologyField = fields[i]   
                biologyField = biologyField.find('span').contents
            if ('Life cycle' in fieldHeader):
                lifeAndMateField = fields[i]   
                lifeAndMateField = lifeAndMateField.find('span').contents
            if ('Red List' in fieldHeader):
                redListStatusField = fields[i]
                redListStatusField = redListStatusField.find('span').contents
            if ('Threat to humans' in fieldHeader):
                threatToHumansField = fields[i]  
                threatToHumansField = threatToHumansField.find('span').contents
            if ('Human uses' in fieldHeader):
                humanUsesField = fields[i]   
                humanUsesField = humanUsesField.find('span').contents
            if ('Estimates of' in fieldHeader):
                estimatesPropertiesField = fields[i]

        # Classification and Etymology
        # Multiple types of content (Text, Tag, NonType). Tags need the get_text(). NonType should be removed. Use rstrip() to remove white spaces at the end of text.
        if (classificationField != False): # If there is no field all variables are nan.
            classification = ''
            etymology = ''
            for field in classificationField.contents:
                if ('Etymology' in str(field)):
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    etymology = field.split("Etymology: ",1)[1] # Split text in 2 parts and get the second.
                    continue 
                if (type(field.find('a')) == int): # If the field contains no <a> tags.
                    field = re.sub(r"[\n\t\r]*", "", field)
                    classification += field+" "

                elif (type(field.find('a')) is bs4.element.Tag): # If the field contains <a> tags.
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    classification += field+" "
                else: # If the field is NonType (like <br/>).     
                    continue

            if (classification==''):
                classification = np.nan
            else:
                classification = classification.rstrip() 
            if (etymology==''):
                etymology = np.nan
            else:
                etymology = re.sub(r'[^\x00-\x7f]',r'',etymology.rstrip())
                etymology = re.sub('(\(Ref.)+ \d*\)', '', etymology) # Remove strings like (Ref. 1234)
        else:
            classification = np.nan
            etymology = np.nan



        # Environment, Climate Zone, Depth, Distribution Coordinates
        #I used .extract() which removes all tags and their content. In this case it the the url tags, which we don't need. A bit of text preprocessing. Use re.search and get text in between for depth range and usual range. Use the same re to get string before substring. Use split(,1) to get text after a substring. Use re to distinguish numbers. Use try-except to handle errors.
        if (environmentField != False):
            environmentInfo = ''
            for field in environmentField:
                field = field.extract()
                field = re.sub(r"[\n\t\r]*", "", field)
                environmentInfo += field
            environmentInfo = re.sub(r'[^\x00-\x7f]',r'',environmentInfo.rstrip())
            environmentInfo = environmentInfo.replace('(Ref. )', '')

            # Get environment values
            try:
                beforeDepthRange = re.search('(.+?)depth range', environmentInfo).group(1).strip() # Match whater is before specific string
                environment = ''
                for value in beforeDepthRange.split(';'):
                    if (':' not in value):
                        environment += value+","
                environment = re.sub('( ){2,}', ' ', environment) # Make 2 or more spaces 1.
                environment = environment.rstrip(',')
            except AttributeError:
                environment = np.nan 

            # Look for depth range in environmentInfo.
            try:
                depthRange = re.search('depth range(.+?)m', environmentInfo).group(1).strip() # Match everything between 2 specific strings.
            except AttributeError:
                depthRange = np.nan 

            # Look for usual range in environmentInfo.
            try:
                usualRange = re.search('usually(.+?)m', environmentInfo).group(1).strip()
            except AttributeError:
                usualRange = np.nan     

            # Look for distribution range in environmentInfo.
            try:
                distributionRange = environmentInfo.split("m . ",1)[1]
                distributionRangeName = ''
                for value in distributionRange.split(';'): # Split in case many locations exist.

                    if (bool(re.search(r'\d', value)) is False):
                        distributionRangeName += value
                    else:
                        distributionRangeCoordinates = value.strip()
            except IndexError:
                try:
                    distributionRange = environmentInfo.split("m. ",1)[1] # Split and get 2nd part.
                    distributionRangeName = ''
                    for value in distributionRange.split(';'): # Split in case many locations exist.

                        if (bool(re.search(r'\d', value)) is False):
                            distributionRangeName += value
                        else:
                            distributionRangeCoordinates = value.strip()
                except IndexError:             
                    distributionRangeName = np.nan
                    distributionRangeCoordinates = np.nan   

        else:
            environment = np.nan
            depthRange = np.nan
            usualRange = np.nan
            distributionRangeName = np.nan
            distributionRangeCoordinates = np.nan


        # Distribution Description
        if (distributionField != False):    
            distributionDescriptionInfo = ''
            for field in distributionField:
                field = field.extract()
                field = re.sub(r"[\n\t\r]*", "", field)
                distributionDescriptionInfo += field
            distributionDescriptionInfo = re.sub(r'[^\x00-\x7f]',r'',distributionDescriptionInfo.rstrip())
            distributionDescriptionInfo = distributionDescriptionInfo.replace('(Ref. )', '')

            distributionDescription = distributionDescriptionInfo

        else:
            distributionDescription = np.nan


        # Length, Weight, Age
        if (metricsField != False):    
            metricsInfo = ''
            for field in metricsField:
                field = field.extract()
                field = re.sub(r"[\n\t\r]*", "", field)    
                metricsInfo += field
            metricsInfo = re.sub(r'[^\x00-\x7f]',r'',metricsInfo.rstrip())
            metricsInfo = metricsInfo.replace('(Ref. )', '')

            try:
                sizeRange = re.search('range(.+?)cm', metricsInfo).group(1).strip()
            except AttributeError:
                sizeRange = np.nan   

            try:
                maxLength = re.search('Max length :(.+?)cm', metricsInfo).group(1).strip()
                maxLength = maxLength.replace(',','')
            except AttributeError:
                maxLength = np.nan    

            try:
                commonLength = re.search('common length :(.+?)cm', metricsInfo).group(1).strip()
                commonLength = commonLength.replace(',','')
            except AttributeError:
                commonLength = np.nan 

            try:
                maxWeight = re.search('max. published weight:(.+?)kg', metricsInfo).group(1).strip()
                maxWeight = maxWeight.replace(',','')
            except AttributeError:
                maxWeight = np.nan         

            try:
                maxAge = re.search('max. reported age:(.+?)years', metricsInfo).group(1).strip()
            except AttributeError:
                maxAge = np.nan

        else:
            sizeRange = np.nan
            maxLength = np.nan
            commonLength = np.nan
            maxWeight = np.nan
            maxAge = np.nan


        # Short Description and other metrics
        if (shortDescriptionField != False):    
            shortDescriptionInfo = ''
            for field in shortDescriptionField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    shortDescriptionInfo += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    shortDescriptionInfo += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            shortDescriptionInfo = shortDescriptionInfo.rstrip()      
            shortDescriptionInfo = re.sub(r'[^\x00-\x7f]',r'',shortDescriptionInfo.rstrip())
            shortDescriptionInfo = re.sub('( \(Ref.)  \d* \)', '', shortDescriptionInfo) 
            shortDescriptionInfo = re.sub('( \(Ref.)  \d* ,  \d* \)', '', shortDescriptionInfo) 

            try:
                dorsalSpines = re.search('Dorsal  spines \(total\):(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
            except AttributeError:
                dorsalSpines = np.nan

            try:
                dorsalSoftRays = re.search('Dorsal  soft rays \(total\):(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
            except AttributeError:
                dorsalSoftRays = np.nan
            dorsalSoftRays

            try:
                analSpines = re.search('Anal  spines : (.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
            except AttributeError:
                analSpines = np.nan

            try:
                analSoftRays = re.search('Anal  soft rays :(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
            except AttributeError:
                analSoftRays = np.nan

            try:
                vertebrae = re.search('Vertebrae :(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
            except AttributeError:
                vertebrae = np.nan

            shortDescription = ''
            if (len(shortDescriptionInfo.split('.'))==2 and 'Dorsal  spines' not in shortDescriptionInfo.split('.')[0]):
                shortDescription = shortDescriptionInfo.split('.')[0]
            elif ('Dorsal  spines' not in shortDescriptionInfo.split('.')[0]):
                for line in shortDescriptionInfo.split('.')[0:]:
                    shortDescription += line
                shortDescription += '.'        
            else:
                for line in shortDescriptionInfo.split('.')[1:]:
                    shortDescription += line
                shortDescription += '.'
            if (shortDescription == ''):
                shortDescription = np.nan
        else:
            dorsalSpines = np.nan
            dorsalSoftRays = np.nan
            analSpines = np.nan
            analSoftRays = np.nan
            vertebrae = np.nan
            shortDescription = np.nan


        # Biology
        if (biologyField != False):
            biologyInfo = ''
            for field in biologyField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    biologyInfo += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    biologyInfo += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            biologyInfo = biologyInfo.rstrip()      
            biologyInfo = re.sub(r'[^\x00-\x7f]',r'',biologyInfo.strip())
            biologyInfo = re.sub('( \(Ref.)  \d* \)', '', biologyInfo)
            biologyInfo = re.sub('\(Ref.  \d* ,  \d* \)', '', biologyInfo)
            biologyInfo = re.sub('\(Ref.  \d* ,  \d* ,  \d* \)', '', biologyInfo)
        else:
            biologyInfo = np.nan


        # Life cycle and mating behavior
        if (lifeAndMateField != False):
            lifeAndMateInfo = ''
            for field in lifeAndMateField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    lifeAndMateInfo += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    lifeAndMateInfo += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            lifeAndMateInfo = lifeAndMateInfo.rstrip()      
            lifeAndMateInfo = re.sub(r'[^\x00-\x7f]',r'',lifeAndMateInfo.strip())  
            lifeAndMateInfo = re.sub('( \(Ref.)  \d* \)', '', lifeAndMateInfo)
            lifeAndMateInfo = re.sub('\(Ref.  \d* ,  \d* \)', '', lifeAndMateInfo)
            lifeAndMateInfo = re.sub('\(Ref.  \d* ,  \d* ,  \d* \)', '', lifeAndMateInfo)
            if (lifeAndMateInfo == ''):
                lifeAndMateInfo = np.nan

        else:
            lifeAndMateInfo = np.nan


        # Red List Status
        if (redListStatusField != False):
            redListStatus = ''
            for field in redListStatusField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    redListStatus += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    redListStatus += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            redListStatus = redListStatus.rstrip()      
            redListStatus = re.sub(r'[^\x00-\x7f]',r'',redListStatus.strip())        
        else:
            redListStatus = np.nan

        # Threat to humans
        if (threatToHumansField != False):
            threatToHumans = ''
            for field in threatToHumansField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    threatToHumans += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    threatToHumans += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            threatToHumans = threatToHumans.rstrip()      
            threatToHumans = re.sub(r'[^\x00-\x7f]',r'',threatToHumans.strip())
            threatToHumans = re.sub('\(Ref. \d* \)', '', threatToHumans)
            threatToHumans = re.sub('\(Ref. \d*\)', '', threatToHumans)
        else:
            threatToHumans = np.nan

        # Human Uses
        if (humanUsesField != False):
            humanUses = ''
            for field in humanUsesField:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    humanUses += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    humanUses += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            if (humanUses.strip() == ''):
                humanUses = np.nan
            else:
                humanUses = humanUses.rstrip()      
                humanUses = re.sub(r'[^\x00-\x7f]',r'',humanUses.strip())        
        else:
            humanUses = np.nan

        # Other properties
        if (estimatesPropertiesField != False):
            propertiesInfo = ''
            for field in estimatesPropertiesField.contents:
                if (type(field) is bs4.element.NavigableString): # if the field contains no <a> tags
                    field = re.sub(r"[\n\t\r]*", "", field)
                    propertiesInfo += field+" "

                elif (type(field) is bs4.element.Tag): # if the field contains <a> tags  
                    field = re.sub(r"[\n\t\r]*", "", field.get_text())
                    propertiesInfo += field+" "

                else: # if the field is NonType (like <br/>)
                    continue
            propertiesInfo = propertiesInfo.rstrip()      
            propertiesInfo = re.sub(r'[^\x00-\x7f]',r'',propertiesInfo.strip()) 
            # Create separator for split()
            propertiesInfo = re.sub(r'Preferred temperature',r'~Preferred temperature ',propertiesInfo)  
            propertiesInfo = re.sub(r'Phylogenetic diversity index',r'~Phylogenetic diversity index ',propertiesInfo)  
            propertiesInfo = re.sub(r'Bayesian length-weight',r'~Bayesian length-weight ',propertiesInfo)  
            propertiesInfo = re.sub(r'Trophic Level',r'~Trophic Level ',propertiesInfo)  
            propertiesInfo = re.sub(r'Resilience',r'~Resilience (Ref ',propertiesInfo)  
            propertiesInfo = re.sub(r'Prior r',r'~Prior r ',propertiesInfo)  
            propertiesInfo = re.sub(r'Vulnerability',r'~Vulnerability ',propertiesInfo)  
            propertiesInfo = re.sub(r'Price category',r'~Price category ',propertiesInfo)  
            propertiesInfo = re.sub('(\(Ref.)+ \d*\)', '', propertiesInfo)
            propertiesInfo = re.sub('(\(Ref.  )+\d*( \))', '', propertiesInfo)
            propertiesInfo = re.sub('(\(Ref)( )*', '', propertiesInfo)

            preferredTemperatureMin = np.nan
            preferredTemperatureMean = np.nan
            preferredTemperatureMax = np.nan
            phylogeneticDiversity = np.nan
            bayesianLengthWeightA = np.nan
            bayesianLengthWeightB = np.nan
            tropicLevel = np.nan
            resilience = np.nan
            priorR = np.nan
            sdRange = np.nan
            vulnerability = np.nan
            priceCategory = np.nan
            for value in propertiesInfo.split('~'):
                try:
                    preferredTemperatureMean = re.search('mean(.+?)\(based', value).group(1).strip()
                    preferredTemperatureMax = re.search('- (.+?),', value).group(1).strip()
                    if ('Bayesian length' not in value):
                        preferredTemperatureMin = re.search(': (.+?) -', value).group(1).strip()
                    cellsBasedOn = re.search('\(based on (.+?)\ cells\)', value).group(1).strip()
                except AttributeError:
                    0    
                try:
                    phylogeneticDiversity = re.search('PD50 =(.+?)\[Uniqueness', value).group(1).strip()
                except AttributeError:
                    0  
                try:
                    bayesianLengthWeightA = re.search('a=(.+?)\(', value).group(1).strip()
                except AttributeError:
                    0 
                try:
                    bayesianLengthWeightB = re.search('b=(.+?)\(', value).group(1).strip()
                except AttributeError:
                    0    
                try:
                    re.search('Trophic Level(.+?)', value).group(1).strip()
                    tropicLevel = value.split("Trophic Level   :",1)[1].strip()
                except AttributeError:
                    0     
                try:
                    re.search('Resilience(.+?)', value).group(1).strip()
                    resilience = value.split("Resilience :",1)[1].strip()
                except AttributeError:
                    0  
                try:
                    priorR = re.search('Prior r  =(.+?),', value).group(1).strip()
                except AttributeError:
                    0 
                try:
                    sdRange = re.search('SD range =(.+?),', value).group(1).strip()
                except AttributeError:
                    0         
                try:
                    re.search('Vulnerability(.+?)', value).group(1).strip()
                    vulnerability = value.split("Vulnerability   :",1)[1].strip()
                except AttributeError:
                    0      
                try:
                    re.search('Price category(.+?)', value).group(1).strip()
                    priceCategory = value.split("Price category   :",1)[1].strip()
                    priceCategory = re.sub(r"\.", "", priceCategory)
                except AttributeError:
                    0      
        else:
            preferredTemperature = np.nan
            phylogeneticDiversity = np.nan
            bayesianLengthWeightA = np.nan
            bayesianLengthWeightB = np.nan
            tropicLevel = np.nan
            resilience = np.nan
            priorR = np.nan
            sdRange = np.nan
            vulnerability = np.nan
            priceCategory = np.nan

        dataset = dataset.append({
                                'scientificName':scientificName,
                                'commonName':commonName,
                                'classification':classification,
                                'etymology':etymology,
                                'environment':environment,
                                'depthRange':depthRange,
                                'usualRange':usualRange,
                                'distributionRangeName':distributionRangeName,
                                'distributionRangeCoordinates':distributionRangeCoordinates,
                                'distributionDescription':distributionDescription,
                                'sizeRange':sizeRange,
                                'maxLength':maxLength,
                                'commonLength':commonLength,
                                'maxWeight':maxWeight,
                                'maxAge':maxAge,
                                'biologyInfo':biologyInfo,
                                'lifeAndMateInfo':lifeAndMateInfo,
                                'redListStatus':redListStatus,
                                'dorsalSpines':dorsalSpines,
                                'dorsalSoftRays':dorsalSoftRays,
                                'analSpines':analSpines,
                                'analSoftRays':analSoftRays,
                                'vertebrae':vertebrae,
                                'shortDescription':shortDescription,
                                'threatToHumans':threatToHumans,
                                'preferredTemperatureMin':preferredTemperatureMin,
                                'preferredTemperatureMean':preferredTemperatureMean,
                                'preferredTemperatureMax':preferredTemperatureMax,
                                'cellsBasedOn':cellsBasedOn,
                                'phylogeneticDiversity':phylogeneticDiversity,
                                'bayesianLengthWeightA':bayesianLengthWeightA,
                                'bayesianLengthWeightB':bayesianLengthWeightB,
                                'resilience':resilience,
                                'priorR':priorR,
                                'sdRange':sdRange,
                                'vulnerability':vulnerability,
                                'priceCategory':priceCategory,
                                'source':website
                                }, ignore_index=True)  
        
    if (website=='ca'):
        
        # Initialize every final variable to nan
        commonName, classification, etymology, environment, depthRange, usualRange, distributionRangeName, distributionRangeCoordinates, distributionDescription = np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan
        sizeRange, maxLength, commonLength, maxWeight, maxAge, biologyInfo, lifeAndMateInfo, redListStatus = np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan, np.nan
        dorsalSpines, dorsalSoftRays, analSpines, analSoftRays, vertebrae, shortDescription, threatToHumans, preferredTemperatureMin, preferredTemperatureMean, preferredTemperatureMax, cellsBasedOn = np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan
        phylogeneticDiversity, bayesianLengthWeightA, bayesianLengthWeightB, resilience, priorR, sdRange, vulnerability, priceCategory = np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan,np.nan

        # Collect scientific name of species
        scientificName = ''
        divScientificName = soup.find(id='ss-sciname') # Find a specific id in html
        divScientificNameUrls = divScientificName.find('b')
        scientificName = divScientificNameUrls.contents[0]
        scientificName

        # Collect common name
        commonName = soup.find(class_='sheader2').contents[0]
        commonName = re.sub(r"[\n\t\r]*", "", commonName)
        if (commonName == ''):
            commonName = np.nan    

        # Classification
        classification, etymology = '', ''
        fields = soup.find_all(class_='slabel bottomBorder') 
        for i, field in enumerate(fields):
            if ('Classification / Names' in field.text):
                classification = field.next_sibling.replace('|','>')+field.next_sibling.next_sibling.text+" > "+field.next_sibling.next_sibling.next_sibling.next_sibling.text
                if ('Etymology' in str(classification)):
                    etymology = classification.split("Etymology: ",1)[1] # Split text in 2 parts and get the second.

        classification = re.sub(r"[\n\t\r]*", "", classification)
        etymology = re.sub(r"[\n\t\r]*", "", etymology)
        if (classification==''):
            classification = np.nan
        if (etymology==''):
            etymology = np.nan    

        # I don't initialize them with np.nan from the beginning, because they might exist and be empty ''.
        environmentInfo, distributionDescription, metricsInfo, biologyInfo, lifeAndMateInfo = '', '', '', '', ''
        divMain = soup.find(id='ss-main')
        fields = soup.find_all('span', recursive=True) 
        for i, field in enumerate(fields):
            # Environment, Climate Zone, Depth, Distribution Coordinates
            if ('Ecology' == field.text and 'Ecology' != fields[i+1].text and 'Diet' != fields[i+1].text):
                environmentInfo = fields[i+1].text
                environmentInfo = re.sub(r"[\n\t\r]*", "", environmentInfo)
                environmentInfo = re.sub('(\(Ref. )+\d*(\))', '', environmentInfo)
                environmentInfo = re.sub(r'[^\x00-\x7f]',r'',environmentInfo.rstrip())
                # Get environment values
                try:
                    beforeDepthRange = re.search('(.+?)depth range', environmentInfo).group(1).strip() # Match whater is before specific string
                    environment = ''
                    for value in beforeDepthRange.split(';'):
                        if (':' not in value):
                            environment += value+","
                    environment = re.sub('( ){2,}', ' ', environment) # Make 2 or more spaces 1.
                    environment = environment.rstrip(' ,')
                except AttributeError:
                    environment = np.nan  

                # Look for depth range in environmentInfo.
                try:
                    depthRange = re.search('depth range(.+?)m', environmentInfo).group(1).strip() # Match everything between 2 specific strings.
                except AttributeError:
                    depthRange = np.nan     

                try:
                    usualRange = re.search('usually(.+?)m', environmentInfo).group(1).strip()
                except AttributeError:
                    usualRange = np.nan   

                # Look for distribution range in environmentInfo.
                try:
                    distributionRange = environmentInfo.split("m . ",1)[1]
                    distributionRangeName = ''
                    for value in distributionRange.split(';'): # Split in case many locations exist.

                        if (bool(re.search(r'(\d*C)', value)) is True):
                            distributionRangeName += value                
                        elif (bool(re.search(r'\d', value)) is False):
                            distributionRangeName += value
                        else:
                            distributionRangeCoordinates = value.strip()
                except IndexError:
                    try:
                        distributionRange = environmentInfo.split("m. ",1)[1] # Split and get 2nd part.
                        distributionRangeName = ''
                        for value in distributionRange.split(';'): # Split in case many locations exist.

                            if (bool(re.search(r'\d', value)) is False):
                                distributionRangeName += value
                            else:
                                distributionRangeCoordinates = value.strip()
                    except IndexError:             
                        distributionRangeName = np.nan
                        distributionRangeCoordinates = np.nan   

            # Distribution Description
            if ('Introductions' == field.text and 'Stocks' != fields[i+1].text):
                distributionDescription = fields[i+1].text.strip()                 

            # Length, Weight, Age   
            if ('Glossary' in field.text and 'Glossary' not in fields[i-1].text):
                metricsInfo = fields[i-1].text
                metricsInfo = re.sub('(\(Ref. )+\d*(\))', '', metricsInfo)
                metricsInfo = re.sub(r'[^\x00-\x7f]',r'',metricsInfo.strip())

                try:
                    sizeRange = re.search('range(.+?)cm', metricsInfo).group(1).strip()
                except AttributeError:
                    sizeRange = np.nan   

                try:
                    maxLength = re.search('Max length :(.+?)cm', metricsInfo).group(1).strip()
                    maxLength = maxLength.replace(',','')
                except AttributeError:
                    maxLength = np.nan    

                try:
                    commonLength = re.search('common length :(.+?)cm', metricsInfo).group(1).strip()
                    commonLength = commonLength.replace(',','')
                except AttributeError:
                    commonLength = np.nan 

                try:
                    maxWeight = re.search('max. published weight:(.+?)kg', metricsInfo).group(1).strip()
                    maxWeight = maxWeight.replace(',','')
                except AttributeError:
                    maxWeight = np.nan         

                try:
                    maxAge = re.search('max. reported age:(.+?)years', metricsInfo).group(1).strip()
                except AttributeError:
                    maxAge = np.nan   

            # Biology        
            if ('(e.g.  epibenthic)' in field.text and 'Glossary' not in fields[i+1].text):
                biologyInfo = fields[i+1].text
                biologyInfo = re.sub(r'[^\x00-\x7f]',r'',biologyInfo.strip())
                biologyInfo = re.sub('(\(Ref.) \d*\)', '', biologyInfo)
                biologyInfo = re.sub('(\(Ref. )\d*, p. \d*\)', '', biologyInfo)
                biologyInfo = re.sub('( \(Ref.)  \d* \)', '', biologyInfo)
                biologyInfo = re.sub('\(Ref.  \d* ,  \d* \)', '', biologyInfo)
                biologyInfo = re.sub('\(Ref.  \d* ,  \d* ,  \d* \)', '', biologyInfo)        

            # Life cycle and mating behavior    
            if ('Larvae' == field.text and 'Abundance' != fields[i+1].text):
                lifeAndMateInfo = fields[i+1].text  
                lifeAndMateInfo = lifeAndMateInfo.rstrip()      
                lifeAndMateInfo = re.sub(r'[^\x00-\x7f]',r'',lifeAndMateInfo.strip())  
                lifeAndMateInfo = re.sub('( \(Ref.)  \d* \)', '', lifeAndMateInfo)
                lifeAndMateInfo = re.sub('\(Ref.  \d* ,  \d* \)', '', lifeAndMateInfo)
                lifeAndMateInfo = re.sub('\(Ref.  \d* ,  \d* ,  \d* \)', '', lifeAndMateInfo)    

        if (environmentInfo == ''):
            environment = np.nan
            depthRange = np.nan
            usualRange = np.nan
            distributionRangeName = np.nan
            distributionRangeCoordinates = np.nan
        if (distributionDescription == ''):
            distributionDescription = np.nan    
        if (metricsInfo == ''):
            sizeRange = np.nan
            maxLength = np.nan
            commonLength = np.nan
            maxWeight = np.nan
            maxAge = np.nan 
        if (biologyInfo == ''):
            biologyInfo = np.nan    
        if (lifeAndMateInfo == ''):
            lifeAndMateInfo = np.nan  

        # Red List Status
        redListStatus = ''
        urls = soup.find_all('a', recursive=True) 
        fields = soup.find_all('a', href=True) 
        for i, field in enumerate(fields):
            if ('www.iucnredlist.org' in field['href']):
                redListStatus = field.text
                redListStatus = re.sub(r"[\n\t\r]*", "", redListStatus)

        if (redListStatus == ''):
            redListStatus = np.nan  

        # Short Description and other metrics,
        shortDescriptionInfo, threatToHumans, humanUses= '', '', ''
        fields = soup.find_all(class_='slabel bottomBorder') 
        for i, field in enumerate(fields):
            if ('Short description' in field.text): # Short Description
                shortDescriptionInfo = field.next_sibling.next_sibling.text
                shortDescriptionInfo = re.sub(r'[^\x00-\x7f]',r'',shortDescriptionInfo.strip())
                shortDescriptionInfo = re.sub('( \(Ref.)  \d* \)', '', shortDescriptionInfo) 
                shortDescriptionInfo = re.sub('( \(Ref.)  \d* ,  \d* \)', '', shortDescriptionInfo) 

                try:
                    dorsalSpines = re.search('Dorsal  spines \(total\):(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
                except AttributeError:
                    dorsalSpines = np.nan

                try:
                    dorsalSoftRays = re.search('Dorsal  soft rays \(total\):(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
                except AttributeError:
                    dorsalSoftRays = np.nan
                dorsalSoftRays

                try:
                    analSpines = re.search('Anal  spines : (.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
                except AttributeError:
                    analSpines = np.nan

                try:
                    analSoftRays = re.search('Anal  soft rays :(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
                except AttributeError:
                    analSoftRays = np.nan

                try:
                    vertebrae = re.search('Vertebrae :(.+?)(\.|;)', shortDescriptionInfo).group(1).strip()
                except AttributeError:
                    vertebrae = np.nan

                shortDescription = ''
                if (len(shortDescriptionInfo.split('.'))==2 and 'Dorsal  spines' not in shortDescriptionInfo.split('.')[0]):
                    shortDescription = shortDescriptionInfo.split('.')[0]
                elif ('Dorsal  spines' not in shortDescriptionInfo.split('.')[0]):
                    for line in shortDescriptionInfo.split('.')[0:]:
                        shortDescription += line
                    shortDescription += '.'        
                else:
                    for line in shortDescriptionInfo.split('.')[1:]:
                        shortDescription += line
                    shortDescription += '.'    


            # Threat to humans
            if ('Threat to humans ' in field.text): # Threat to humans
                threatToHumans = field.next_sibling.next_sibling.text
                threatToHumans = re.sub(r'[^\x00-\x7f]',r'',threatToHumans.strip())      
                threatToHumans = re.sub('\(Ref. \d* \)', '', threatToHumans)
                threatToHumans = re.sub('\(Ref. \d*\)', '', threatToHumans)
            
            # Human Uses
            if ('Human uses' in field.text): # Human Uses
                humanUses = field.next_sibling.next_sibling.text
                humanUses = re.sub(r'[^\x00-\x7f]',r'',humanUses.strip()) 

        # Other properties  
        preferredTemperatureMean, preferredTemperatureMin, preferredTemperatureMax, phylogeneticDiversity, bayesianLengthWeightA, bayesianLengthWeightB, tropicLevel, resilience, priorR, sdRange, vulnerability, priceCategory= '','','', '', '', '', '', '', '', '', '', ''
        fields = soup.find_all(class_='slabel') 
        for i, field in enumerate(fields):
            if ('Preferred temperature' in field.text): # Preferred temperature
                preferredTemperatureInfo = field.next_sibling.next_sibling.next_sibling.strip()
                preferredTemperatureMean = re.search('mean(.+?)\(based', preferredTemperatureInfo).group(1).strip()
                if ('Bayesian length' not in preferredTemperatureInfo):
                    preferredTemperatureMin = re.search(': (.+?) -', preferredTemperatureInfo).group(1).strip()
                cellsBasedOn = re.search('\(based on (.+?)\ cells\)', preferredTemperatureInfo).group(1).strip()
                preferredTemperatureMax = re.search('- (.+?),', preferredTemperatureInfo).group(1).strip()
            if ('Vulnerability' in field.text): # Vulnerability
                vulnerability = field.next_sibling.next_sibling.next_sibling.next_sibling.text.strip()  
            if ('Price category' in field.text): # Price category
                priceCategory = field.next_sibling.next_sibling.next_sibling.next_sibling.text.strip()

        if (shortDescription == ''):
            dorsalSpines = np.nan
            dorsalSoftRays = np.nan
            analSpines = np.nan
            analSoftRays = np.nan
            vertebrae = np.nan
            shortDescription = np.nan
        if (threatToHumans == ''):  
            threatToHumans = np.nan
        if (humanUses == ''):  
            humanUses = np.nan
        if (preferredTemperatureMin == ''):  
            preferredTemperatureMin = np.nan 
        if (preferredTemperatureMean == ''):  
            preferredTemperatureMean = np.nan                
        if (preferredTemperatureMax == ''):  
            preferredTemperatureMax = np.nan       
        if (cellsBasedOn == ''):  
            cellsBasedOn = np.nan               
        if (phylogeneticDiversity == ''):  
            phylogeneticDiversity = np.nan  
        if (bayesianLengthWeightA == ''):  
            bayesianLengthWeightA = np.nan      
        if (bayesianLengthWeightB == ''):  
            bayesianLengthWeightB = np.nan      
        if (resilience == ''):  
            resilience = np.nan      
        if (priorR == ''):  
            priorR = np.nan      
        if (sdRange == ''):  
            sdRange = np.nan      
        if (vulnerability == ''):  
            vulnerability = np.nan      
        if (priceCategory == ''):  
            priceCategory = np.nan

        dataset = dataset.append({
                                'scientificName':scientificName,
                                'commonName':commonName,
                                'classification':classification,
                                'etymology':etymology,
                                'environment':environment,
                                'depthRange':depthRange,
                                'usualRange':usualRange,
                                'distributionRangeName':distributionRangeName,
                                'distributionRangeCoordinates':distributionRangeCoordinates,
                                'distributionDescription':distributionDescription,
                                'sizeRange':sizeRange,
                                'maxLength':maxLength,
                                'commonLength':commonLength,
                                'maxWeight':maxWeight,
                                'maxAge':maxAge,
                                'biologyInfo':biologyInfo,
                                'lifeAndMateInfo':lifeAndMateInfo,
                                'redListStatus':redListStatus,
                                'dorsalSpines':dorsalSpines,
                                'dorsalSoftRays':dorsalSoftRays,
                                'analSpines':analSpines,
                                'analSoftRays':analSoftRays,
                                'vertebrae':vertebrae,
                                'shortDescription':shortDescription,
                                'threatToHumans':threatToHumans,
                                'preferredTemperatureMin':preferredTemperatureMin,
                                'preferredTemperatureMean':preferredTemperatureMean,
                                'preferredTemperatureMax':preferredTemperatureMax,
                                'cellsBasedOn':cellsBasedOn,
                                'phylogeneticDiversity':phylogeneticDiversity,
                                'bayesianLengthWeightA':bayesianLengthWeightA,
                                'bayesianLengthWeightB':bayesianLengthWeightB,
                                'resilience':resilience,
                                'priorR':priorR,
                                'sdRange':sdRange,
                                'vulnerability':vulnerability,
                                'priceCategory':priceCategory,
                                'source':website
                                }, ignore_index=True)
# Out:
# Using www.sealifebase.ca for	: Abra alba
# Using www.sealifebase.ca for	: Abralia veranyi
# Using www.sealifebase.ca for	: Abraliopsis pfefferi
# Using www.sealifebase.ca for	: Abylopsis tetragona
# Using www.sealifebase.ca for	: Acanthocardia aculeata
# Using www.sealifebase.ca for	: Acanthocardia echinata
# Using www.sealifebase.ca for	: Acanthocardia paucicostata
# Using www.sealifebase.ca for	: Acanthocardia spinosa
# Using www.sealifebase.ca for	: Acanthocardia tuberculata
# Using www.sealifebase.ca for	: Acanthochitona fascicularis
# Using www.fishbase.de for	: Acanthocybium solandri
# Using www.sealifebase.ca for	: Acanthodasys aculeatus
# Using www.fishbase.de for	: Acantholabrus palloni
# Using www.sealifebase.ca for	: Acanthomysis longicornis
# Using www.sealifebase.ca for	: Acar plicata
# Using www.fishbase.de for	: Acipenser gueldenstaedtii
# Using www.fishbase.de for	: Acipenser naccarii
# Using www.fishbase.de for	: Acipenser nudiventris
# Using www.fishbase.de for	: Acipenser stellatus
# Using www.fishbase.de for	: Acipenser sturio
# Using www.sealifebase.ca for	: Acryptolaria conferta
# Using www.sealifebase.ca for	: Actinauge richardi
# Using www.sealifebase.ca for	: Actinia equina
# Using www.sealifebase.ca for	: Adamsia palliata
# Using www.sealifebase.ca for	: Aega deshaysiana
# Using www.sealifebase.ca for	: Aegaeon lacazei
# Using www.sealifebase.ca for	: Aequipecten opercularis
# Using www.sealifebase.ca for	: Aetea sica
# Using www.sealifebase.ca for	: Aetea truncata
# Using www.fishbase.de for	: Aetomylaeus bovinus
# Using www.fishbase.de for	: Aidablennius sphynx
# Using www.sealifebase.ca for	: Aiptasia mutabilis
# Using www.sealifebase.ca for	: Alcyonium coralloides
# Using www.sealifebase.ca for	: Alcyonium palmatum
# Using www.fishbase.de for	: Alectis alexandrina
# Using www.fishbase.de for	: Alepisaurus ferox
# Using www.fishbase.de for	: Alepocephalus rostratus
# Using www.sealifebase.ca for	: Alicia mirabilis
# Using www.sealifebase.ca for	: Allosergestes sargassi
# Using www.sealifebase.ca for	: Alloteuthis subulata
# Using www.fishbase.de for	: Alopias superciliosus
# Using www.fishbase.de for	: Alopias vulpinus
# Using www.fishbase.de for	: Alosa alosa
# Using www.fishbase.de for	: Alosa fallax
# Using www.fishbase.de for	: Alosa tanaica
# Using www.sealifebase.ca for	: Alpheus lobidens
# Using www.sealifebase.ca for	: Alvania cancellata
# Using www.sealifebase.ca for	: Amathia vidovici
# Using www.sealifebase.ca for	: Amathina tricarinata
# Using www.fishbase.de for	: Ammodytes tobianus
# Using www.sealifebase.ca for	: Ampelisca brevicornis
# Using www.sealifebase.ca for	: Amphibalanus amphitrite
# Using www.sealifebase.ca for	: Amphicteis gunneri
# Using www.sealifebase.ca for	: Amphiglena mediterranea
# Using www.sealifebase.ca for	: Amphilepis norvegica
# Using www.sealifebase.ca for	: Amphipholis squamata
# Using www.sealifebase.ca for	: Amphiura cherbonnieri
# Using www.sealifebase.ca for	: Amphiura chiajei
# Using www.sealifebase.ca for	: Ampithoe ramondi
# Using www.sealifebase.ca for	: Anadara diluvii
# Using www.sealifebase.ca for	: Anadara inaequivalvis
# Using www.fishbase.de for	: Anarchias euryurus
# Using www.sealifebase.ca for	: Anchialina agilis
# Using www.sealifebase.ca for	: Ancistroteuthis lichtensteini
# Using www.sealifebase.ca for	: Anemonactis mazeli
# Using www.sealifebase.ca for	: Anemonia sulcata
# Using www.fishbase.de for	: Anguilla anguilla
# Using www.sealifebase.ca for	: Anodontia fragilis
# Using www.sealifebase.ca for	: Anomia ephippium
# Using www.sealifebase.ca for	: Anoplodactylus angulatus
# Using www.sealifebase.ca for	: Anoplodactylus californicus
# Using www.sealifebase.ca for	: Anseropoda placenta
# Using www.sealifebase.ca for	: Antalis agilis
# Using www.sealifebase.ca for	: Antalis circumcincta
# Using www.sealifebase.ca for	: Antalis dentalis
# Using www.sealifebase.ca for	: Antalis inaequicostata
# Using www.sealifebase.ca for	: Antalis panorma
# Using www.sealifebase.ca for	: Antalis vulgaris
# Using www.sealifebase.ca for	: Antedon mediterranea
# Using www.fishbase.de for	: Anthias anthias
# Using www.sealifebase.ca for	: Anthopleura ballii
# Using www.sealifebase.ca for	: Anthopleura thallia
# Using www.sealifebase.ca for	: Anthura gracilis
# Using www.sealifebase.ca for	: Antipathes dichotoma
# Using www.sealifebase.ca for	: Aonides oxycephala
# Using www.sealifebase.ca for	: Apanthura corsica
# Using www.fishbase.de for	: Aphanius fasciatus
# Using www.sealifebase.ca for	: Aphelochaeta filiformis
# Using www.sealifebase.ca for	: Aphelochaeta marioni
# Using www.fishbase.de for	: Aphia minuta
# Using www.sealifebase.ca for	: Apionsoma murinae
# Using www.sealifebase.ca for	: Apionsoma trichocephalus
# Using www.fishbase.de for	: Apletodon dentatus
# Using www.fishbase.de for	: Apletodon incognitus
# Using www.sealifebase.ca for	: Aplysia fasciata
# Using www.sealifebase.ca for	: Aplysia parvula
# Using www.sealifebase.ca for	: Aplysia punctata
# Using www.sealifebase.ca for	: Aplysiopsis formosa
# Using www.fishbase.de for	: Apogon imberbis
# Using www.sealifebase.ca for	: Apomatus similis
# Using www.sealifebase.ca for	: Apseudes talpa
# Using www.fishbase.de for	: Apterichtus anguiformis
# Using www.fishbase.de for	: Apterichtus caecus
# Using www.sealifebase.ca for	: Arabella iricolor
# Using www.sealifebase.ca for	: Arachnomysis leuckartii
# Using www.sealifebase.ca for	: Arbacia lixula
# Using www.sealifebase.ca for	: Arca noae
# Using www.sealifebase.ca for	: Arca tetragona
# Using www.sealifebase.ca for	: Arcoscalpellum michelottianum
# Using www.fishbase.de for	: Arctozenus risso
# Using www.fishbase.de for	: Argentina sphyraena
# Using www.sealifebase.ca for	: Argonauta argo
# Using www.fishbase.de for	: Argyropelecus hemigymnus
# Using www.fishbase.de for	: Argyrosomus regius
# Using www.sealifebase.ca for	: Argyrotheca cistellula
# Using www.fishbase.de for	: Ariosoma balearicum
# Using www.sealifebase.ca for	: Aristaeomorpha foliacea
# Using www.sealifebase.ca for	: Aristeus antennatus
# Using www.fishbase.de for	: Arnoglossus imperialis
# Using www.fishbase.de for	: Arnoglossus kessleri
# Using www.fishbase.de for	: Arnoglossus laterna
# Using www.fishbase.de for	: Arnoglossus rueppelii
# Using www.fishbase.de for	: Arnoglossus thori
# Using www.sealifebase.ca for	: Ascaltis lamarcki
# Using www.sealifebase.ca for	: Ascidia mentula
# Using www.sealifebase.ca for	: Ascidiella aspersa
# Using www.sealifebase.ca for	: Ascorhynchus castelli
# Using www.sealifebase.ca for	: Asparagopsis armata
# Using www.sealifebase.ca for	: Asparagopsis taxiformis
# Using www.sealifebase.ca for	: Aspidiophorus paramediterraneus
# Using www.sealifebase.ca for	: Aspidosiphon misakiensis
# Using www.sealifebase.ca for	: Aspidosiphon muelleri
# Using www.sealifebase.ca for	: Asterina gibbosa
# Using www.sealifebase.ca for	: Astroides calycularis
# Using www.sealifebase.ca for	: Astropecten aranciacus
# Using www.sealifebase.ca for	: Astropecten bispinosus
# Using www.sealifebase.ca for	: Astropecten jonstoni
# Using www.sealifebase.ca for	: Astropecten spinulosus
# Using www.sealifebase.ca for	: Astrospartus mediterraneus
# Using www.fishbase.de for	: Atherina boyeri
# Using www.fishbase.de for	: Atherina hepsetus
# Using www.fishbase.de for	: Atherina presbyter
# Using www.sealifebase.ca for	: Atlanta peronii
# Using www.sealifebase.ca for	: Atrina pectinata
# Using www.sealifebase.ca for	: Aulactinia verrucosa
# Using www.fishbase.de for	: Aulopus filamentosus
# Using www.fishbase.de for	: Aulotrachichthys sajademalensis
# Using www.sealifebase.ca for	: Aurelia aurita
# Using www.sealifebase.ca for	: Automate branchialis
# Using www.fishbase.de for	: Auxis rochei
# Using www.fishbase.de for	: Auxis thazard
# Using www.sealifebase.ca for	: Balaenoptera acutorostrata
# Using www.sealifebase.ca for	: Balanophyllia europaea
# Using www.sealifebase.ca for	: Balanus improvisus
# Using www.fishbase.de for	: Balistes capriscus
# Using www.sealifebase.ca for	: Barbatia barbata
# Using www.sealifebase.ca for	: Barbatia clathrata
# Using www.fishbase.de for	: Bathophilus nigerrimus
# Using www.fishbase.de for	: Bathophilus vaillanti
# Using www.sealifebase.ca for	: Bathyarca frielei
# Using www.sealifebase.ca for	: Bathyarca grenophia
# Using www.sealifebase.ca for	: Bathyarca philippiana
# Using www.sealifebase.ca for	: Bathynectes maravigna
# Using www.sealifebase.ca for	: Bathypolypus sponsalis
# Using www.fishbase.de for	: Bathypterois dubius
# Using www.fishbase.de for	: Bathysolea profundicola
# Using www.sealifebase.ca for	: Beania hirtissima
# Using www.sealifebase.ca for	: Beania magellanica
# Using www.sealifebase.ca for	: Beania mirabilis
# Using www.fishbase.de for	: Bellottia apoda
# Using www.fishbase.de for	: Belone belone
# Using www.fishbase.de for	: Belone svetovidovi
# Using www.sealifebase.ca for	: Benthomangelia macra
# Using www.sealifebase.ca for	: Benthonella tenella
# Using www.fishbase.de for	: Benthosema glaciale
# Using www.sealifebase.ca for	: Berthella stellata
# Using www.fishbase.de for	: Beryx decadactylus
# Using www.sealifebase.ca for	: Bhawania goodei
# Using www.sealifebase.ca for	: Bispira crassicornis
# Using www.sealifebase.ca for	: Bittium reticulatum
# Using www.fishbase.de for	: Blennius ocellaris
# Using www.sealifebase.ca for	: Bolinus brandaris
# Using www.sealifebase.ca for	: Bolitaena pygmaea
# Using www.sealifebase.ca for	: Bonellia viridis
# Using www.fishbase.de for	: Boops boops
# Using www.sealifebase.ca for	: Boreomysis arctica
# Using www.sealifebase.ca for	: Boreomysis megalops
# Using www.fishbase.de for	: Bothus podas
# Using www.sealifebase.ca for	: Botryllus schlosseri
# Using www.sealifebase.ca for	: Brachidontes pharaonis
# Using www.sealifebase.ca for	: Brachioteuthis riisei
# Using www.sealifebase.ca for	: Brachycarpus biunguiculatus
# Using www.sealifebase.ca for	: Brachynotus foresti
# Using www.fishbase.de for	: Brama brama
# Using www.sealifebase.ca for	: Branchiosyllis exilis
# Using www.sealifebase.ca for	: Brissopsis lyrifera
# Using www.fishbase.de for	: Buenia affinis
# Using www.fishbase.de for	: Buglossidium luteum
# Using www.sealifebase.ca for	: Bugula neritina
# Using www.sealifebase.ca for	: Bulla ampulla
# Using www.sealifebase.ca for	: Bunodactis rubripunctata
# Using www.sealifebase.ca for	: Bunodeopsis strumosa
# Using www.sealifebase.ca for	: Bursatella leachii
# Using www.sealifebase.ca for	: Buskea dichotoma
# Using www.sealifebase.ca for	: Caberea boryi
# Using www.sealifebase.ca for	: Cadulus propinquus
# Using www.sealifebase.ca for	: Calappa granulata
# Using www.fishbase.de for	: Callanthias ruber
# Using www.sealifebase.ca for	: Calliactis parasitica
# Using www.fishbase.de for	: Callionymus fasciatus
# Using www.fishbase.de for	: Callionymus lyra
# Using www.fishbase.de for	: Callionymus maculatus
# Using www.fishbase.de for	: Callionymus pusillus
# Using www.fishbase.de for	: Callionymus risso
# Using www.sealifebase.ca for	: Callipallene phantoma
# Using www.sealifebase.ca for	: Callipallene producta
# Using www.sealifebase.ca for	: Callista chione
# Using www.sealifebase.ca for	: Callistoctopus macropus
# Using www.sealifebase.ca for	: Callochiton septemvalvis
# Using www.sealifebase.ca for	: Calpensia nobilis
# Using www.sealifebase.ca for	: Calyptraea chinensis
# Using www.fishbase.de for	: Campogramma glaycos
# Using www.sealifebase.ca for	: Capitella capitata
# Using www.fishbase.de for	: Capros aper
# Using www.sealifebase.ca for	: Capulus ungaricus
# Using www.fishbase.de for	: Caranx crysos
# Using www.fishbase.de for	: Caranx hippos
# Using www.fishbase.de for	: Caranx rhonchus
# Using www.fishbase.de for	: Carapus acus
# Using www.fishbase.de for	: Carcharhinus brachyurus
# Using www.fishbase.de for	: Carcharhinus brevipinna
# Using www.fishbase.de for	: Carcharhinus limbatus
# Using www.fishbase.de for	: Carcharhinus longimanus
# Using www.fishbase.de for	: Carcharhinus melanopterus
# Using www.fishbase.de for	: Carcharhinus obscurus
# Using www.fishbase.de for	: Carcharhinus plumbeus
# Using www.fishbase.de for	: Carcharias taurus
# Using www.fishbase.de for	: Carcharodon carcharias
# Using www.sealifebase.ca for	: Carcinus aestuarii
# Using www.sealifebase.ca for	: Cardium edule
# Using www.sealifebase.ca for	: Caretta caretta
# Using www.sealifebase.ca for	: Caryophyllia calveri
# Using www.sealifebase.ca for	: Caryophyllia cyathus
# Using www.sealifebase.ca for	: Caryophyllia inornata
# Using www.sealifebase.ca for	: Caryophyllia smithii
# Using www.fishbase.de for	: Cataetyx alleni
# Using www.fishbase.de for	: Cataetyx laticeps
# Using www.sealifebase.ca for	: Catriona maua
# Using www.sealifebase.ca for	: Caulerpa racemosa
# Using www.sealifebase.ca for	: Cavolinia inflexa
# Using www.sealifebase.ca for	: Cavolinia uncinata
# Using www.sealifebase.ca for	: Cellaria salicornioides
# Using www.fishbase.de for	: Centracanthus cirrus
# Using www.fishbase.de for	: Centrolophus niger
# Using www.fishbase.de for	: Centrophorus uyato
# Using www.fishbase.de for	: Centroscymnus coelolepis
# Using www.sealifebase.ca for	: Centrostephanus longispinus
# Using www.fishbase.de for	: Cepola macrophthalma
# Using www.sealifebase.ca for	: Ceramaster grenadensis
# Using www.sealifebase.ca for	: Ceramium virgatum
# Using www.sealifebase.ca for	: Cerastoderma edule
# Using www.sealifebase.ca for	: Cerastoderma glaucum
# Using www.fishbase.de for	: Ceratoscopelus maderensis
# Using www.sealifebase.ca for	: Cereus pedunculatus
# Using www.sealifebase.ca for	: Cerithiopsis fayalensis
# Using www.fishbase.de for	: Cetorhinus maximus
# Using www.sealifebase.ca for	: Chaceon mediterraneus
# Using www.sealifebase.ca for	: Chaetaster longipes
# Using www.sealifebase.ca for	: Chaetomorpha linum
# Using www.sealifebase.ca for	: Chaetonotus aegilonensis
# Using www.sealifebase.ca for	: Chaetonotus apechochaetus
# Using www.sealifebase.ca for	: Chaetonotus atrox
# Using www.sealifebase.ca for	: Chaetonotus dispar
# Using www.sealifebase.ca for	: Chaetonotus lacunosus
# Using www.sealifebase.ca for	: Chaetopterus variopedatus
# Using www.sealifebase.ca for	: Chamelea gallina
# Using www.sealifebase.ca for	: Charonia lampas
# Using www.fishbase.de for	: Chauliodus sloani
# Using www.fishbase.de for	: Cheilopogon heterurus
# Using www.fishbase.de for	: Chelidonichthys cuculus
# Using www.fishbase.de for	: Chelidonichthys lucerna
# Using www.fishbase.de for	: Chelidonichthys obscurus
# Using www.fishbase.de for	: Chelon labrosus
# Using www.sealifebase.ca for	: Chelonia mydas
# Using www.sealifebase.ca for	: Chelophyes appendiculata
# Using www.sealifebase.ca for	: Chelophyes contorta
# Using www.fishbase.de for	: Chimaera monstrosa
# Using www.sealifebase.ca for	: Chiroteuthis veranyi
# Using www.fishbase.de for	: Chlopsis bicolor
# Using www.fishbase.de for	: Chlorophthalmus agassizi
# Using www.sealifebase.ca for	: Chlorotocus crassicornis
# Using www.sealifebase.ca for	: Chondrosia reniformis
# Using www.sealifebase.ca for	: Chone collaris
# Using www.sealifebase.ca for	: Chone duneri
# Using www.sealifebase.ca for	: Chorizopora brongniartii
# Using www.fishbase.de for	: Chromis chromis
# Using www.fishbase.de for	: Chromogobius quadrivittatus
# Using www.sealifebase.ca for	: Chrysaora hysoscella
# Using www.sealifebase.ca for	: Chrysopetalum debile
# Using www.sealifebase.ca for	: Chtenopteryx sicula
# Using www.sealifebase.ca for	: Chthamalus stellatus
# Using www.sealifebase.ca for	: Cidaris cidaris
# Using www.sealifebase.ca for	: Ciona intestinalis
# Using www.sealifebase.ca for	: Cirolana cranchii
# Using www.sealifebase.ca for	: Cirrophorus branchiatus
# Using www.fishbase.de for	: Citharus linguatula
# Using www.sealifebase.ca for	: Cladocora caespitosa
# Using www.sealifebase.ca for	: Cladonema radiatum
# Using www.sealifebase.ca for	: Clathrina clathrus
# Using www.sealifebase.ca for	: Clausinella fasciata
# Using www.sealifebase.ca for	: Clavularia crassa
# Using www.fishbase.de for	: Clinitrachus argentatus
# Using www.sealifebase.ca for	: Clio cuspidata
# Using www.sealifebase.ca for	: Clio pyramidata
# Using www.sealifebase.ca for	: Cliopsis krohnii
# Using www.fishbase.de for	: Clupeonella cultriventris
# Using www.sealifebase.ca for	: Codium bursa
# Using www.sealifebase.ca for	: Condylactis aurantiaca
# Using www.fishbase.de for	: Conger conger
# Using www.sealifebase.ca for	: Conopea calceolus
# Using www.sealifebase.ca for	: Copidozoum planum
# Using www.sealifebase.ca for	: Corallium rubrum
# Using www.sealifebase.ca for	: Corbula gibba
# Using www.fishbase.de for	: Coris julis
# Using www.sealifebase.ca for	: Cornularia cornucopiae
# Using www.sealifebase.ca for	: Corydendrium parasiticum
# Using www.fishbase.de for	: Coryphaena equiselis
# Using www.fishbase.de for	: Coryphaena hippurus
# Using www.fishbase.de for	: Coryphaenoides mediterraneus
# Using www.fishbase.de for	: Coryphoblennius galerita
# Using www.sealifebase.ca for	: Coscinasterias tenuispina
# Using www.sealifebase.ca for	: Cotylorhiza tuberculata
# Using www.sealifebase.ca for	: Cranchia scabra
# Using www.sealifebase.ca for	: Crangon crangon
# Using www.sealifebase.ca for	: Crassostrea angulata
# Using www.sealifebase.ca for	: Crassostrea virginica
# Using www.sealifebase.ca for	: Crenella decussata
# Using www.sealifebase.ca for	: Crepidula fornicata
# Using www.sealifebase.ca for	: Creseis acicula
# Using www.sealifebase.ca for	: Creseis virgula
# Using www.fishbase.de for	: Crystallogobius linearis
# Using www.sealifebase.ca for	: Ctena decussata
# Using www.fishbase.de for	: Ctenolabrus rupestris
# Using www.fishbase.de for	: Cubiceps gracilis
# Using www.sealifebase.ca for	: Cunina octonaria
# Using www.sealifebase.ca for	: Cuspidaria rostrata
# Using www.sealifebase.ca for	: Cuthona perca
# Using www.sealifebase.ca for	: Cyathura carinata
# Using www.fishbase.de for	: Cyclothone braueri
# Using www.fishbase.de for	: Cyclothone microdon
# Using www.fishbase.de for	: Cyclothone pygmaea
# Using www.sealifebase.ca for	: Cyerce cristallina
# Using www.sealifebase.ca for	: Cymbium olla
# Using www.sealifebase.ca for	: Cymodoce hanseni
# Using www.sealifebase.ca for	: Cystodytes dellechiajei
# Using www.sealifebase.ca for	: Dactylopodola mesotyphle
# Using www.fishbase.de for	: Dactylopterus volitans
# Using www.fishbase.de for	: Dalatias licha
# Using www.fishbase.de for	: Dalophis imberbis
# Using www.sealifebase.ca for	: Dardanus arrosor
# Using www.sealifebase.ca for	: Dardanus calidus
# Using www.fishbase.de for	: Dasyatis centroura
# Using www.fishbase.de for	: Dasyatis pastinaca
# Using www.fishbase.de for	: Dasyatis tortonesei
# Using www.sealifebase.ca for	: Dasybranchus caducus
# Using www.fishbase.de for	: Decapterus macarellus
# Using www.fishbase.de for	: Decapterus punctatus
# Using www.sealifebase.ca for	: Delectopecten vitreus
# Using www.sealifebase.ca for	: Delphinus delphis
# Using www.fishbase.de for	: Deltentosteus quadrimaculatus
# Using www.sealifebase.ca for	: Dendrodoris fumata
# Using www.sealifebase.ca for	: Dendrophyllia cornigera
# Using www.fishbase.de for	: Dentex dentex
# Using www.fishbase.de for	: Dentex macrophthalmus
# Using www.fishbase.de for	: Dentex maroccanus
# Using www.sealifebase.ca for	: Dermochelys coriacea
# Using www.sealifebase.ca for	: Desmophyllum dianthus
# Using www.sealifebase.ca for	: Diacria atlantica
# Using www.sealifebase.ca for	: Diacria trispinosa
# Using www.sealifebase.ca for	: Diadema setosum
# Using www.sealifebase.ca for	: Diadumene lineata
# Using www.fishbase.de for	: Diaphus holti
# Using www.fishbase.de for	: Diaphus metopoclampus
# Using www.fishbase.de for	: Diaphus rafinesquii
# Using www.fishbase.de for	: Dicentrarchus labrax
# Using www.fishbase.de for	: Dicentrarchus punctatus
# Using www.fishbase.de for	: Dicologlossa cuneata
# Using www.sealifebase.ca for	: Dictyota dichotoma
# Using www.sealifebase.ca for	: Didemnum candidum
# Using www.sealifebase.ca for	: Didemnum grande
# Using www.sealifebase.ca for	: Didemnum moseleyi
# Using www.sealifebase.ca for	: Digenea simplex
# Using www.sealifebase.ca for	: Digitaria digitaria
# Using www.fishbase.de for	: Diogenichthys atlanticus
# Using www.sealifebase.ca for	: Diopatra neapolitana
# Using www.sealifebase.ca for	: Diphyes bojani
# Using www.sealifebase.ca for	: Diphyes dispar
# Using www.sealifebase.ca for	: Diplodasys ankeli
# Using www.fishbase.de for	: Diplodus annularis
# Using www.fishbase.de for	: Diplodus cervinus
# Using www.fishbase.de for	: Diplodus puntazzo
# Using www.fishbase.de for	: Diplodus sargus
# Using www.fishbase.de for	: Diplodus vulgaris
# Using www.sealifebase.ca for	: Diplosolen obelium
# Using www.sealifebase.ca for	: Diplosoma listerianum
# Using www.sealifebase.ca for	: Diplosoma macdonaldi
# Using www.sealifebase.ca for	: Dipolydora armata
# Using www.fishbase.de for	: Dipturus batis
# Using www.fishbase.de for	: Dipturus oxyrinchus
# Using www.sealifebase.ca for	: Dipurena halterata
# Using www.sealifebase.ca for	: Disteira major
# Using www.sealifebase.ca for	: Ditrupa arietina
# Using www.sealifebase.ca for	: Dolioletta gegenbaueri
# Using www.sealifebase.ca for	: Doliolum denticulatum
# Using www.sealifebase.ca for	: Donax semistriatus
# Using www.sealifebase.ca for	: Donax trunculus
# Using www.sealifebase.ca for	: Donax venustus
# Using www.sealifebase.ca for	: Doris verrucosa
# Using www.sealifebase.ca for	: Dosinia exoleta
# Using www.sealifebase.ca for	: Dosinia lupinus
# Using www.sealifebase.ca for	: Draculiciteria tesselata
# Using www.sealifebase.ca for	: Drilliola loprestiana
# Using www.sealifebase.ca for	: Drilonereis filum
# Using www.sealifebase.ca for	: Dynamene torelliae
# Using www.fishbase.de for	: Dysomma brevirostre
# Using www.fishbase.de for	: Echelus myrus
# Using www.fishbase.de for	: Echeneis naucrates
# Using www.fishbase.de for	: Echiichthys vipera
# Using www.sealifebase.ca for	: Echinaster sepositus
# Using www.sealifebase.ca for	: Echinocardium mediterraneum
# Using www.fishbase.de for	: Echinorhinus brucus
# Using www.fishbase.de for	: Echiodon dentatus
# Using www.sealifebase.ca for	: Ecteinascidia thurstoni
# Using www.sealifebase.ca for	: Ectopleura dumortierii
# Using www.sealifebase.ca for	: Edwardsia claparedii
# Using www.fishbase.de for	: Electrona risso
# Using www.sealifebase.ca for	: Eledone cirrhosa
# Using www.sealifebase.ca for	: Eledone moschata
# Using www.sealifebase.ca for	: Emydocephalus annulatus
# Using www.sealifebase.ca for	: Endeis spinosa
# Using www.fishbase.de for	: Engraulis encrasicolus
# Using www.sealifebase.ca for	: Ensis siliqua
# Using www.fishbase.de for	: Epigonus constanciae
# Using www.fishbase.de for	: Epigonus denticulatus
# Using www.fishbase.de for	: Epigonus telescopus
# Using www.fishbase.de for	: Epinephelus aeneus
# Using www.fishbase.de for	: Epinephelus caninus
# Using www.fishbase.de for	: Epinephelus costae
# Using www.fishbase.de for	: Epinephelus marginatus
# Using www.sealifebase.ca for	: Epizoanthus arenaceus
# Using www.fishbase.de for	: Eretmophorus kleinenbergi
# Using www.sealifebase.ca for	: Erinaceusyllis belizensis
# Using www.sealifebase.ca for	: Eriphia verrucosa
# Using www.sealifebase.ca for	: Erythrops elegans
# Using www.sealifebase.ca for	: Erythrops erythrophthalma
# Using www.sealifebase.ca for	: Erythrops neapolitana
# Using www.sealifebase.ca for	: Escharina vulgaris
# Using www.fishbase.de for	: Etmopterus spinax
# Using www.fishbase.de for	: Etrumeus sadina
# Using www.sealifebase.ca for	: Euchaetomera glyphidophthalmica
# Using www.sealifebase.ca for	: Euchaetomera tenuis
# Using www.sealifebase.ca for	: Eucheilota paradoxica
# Using www.sealifebase.ca for	: Eucidaris tribuloides
# Using www.sealifebase.ca for	: Eucopia hanseni
# Using www.sealifebase.ca for	: Eudendrium armatum
# Using www.sealifebase.ca for	: Eudendrium capillare
# Using www.sealifebase.ca for	: Eudendrium carneum
# Using www.sealifebase.ca for	: Eudendrium fragile
# Using www.sealifebase.ca for	: Eudendrium glomeratum
# Using www.sealifebase.ca for	: Eudendrium merulum
# Using www.sealifebase.ca for	: Eudendrium racemosum
# Using www.sealifebase.ca for	: Eudendrium rameum
# Using www.sealifebase.ca for	: Eudendrium ramosum
# Using www.sealifebase.ca for	: Eulalia viridis
# Using www.sealifebase.ca for	: Eulima glabra
# Using www.sealifebase.ca for	: Eumida sanguinea
# Using www.sealifebase.ca for	: Eunice antennata
# Using www.sealifebase.ca for	: Eunice vittata
# Using www.sealifebase.ca for	: Eunicella cavolini
# Using www.sealifebase.ca for	: Eunicella singularis
# Using www.sealifebase.ca for	: Eunicella verrucosa
# Using www.sealifebase.ca for	: Euphrosine foliosa
# Using www.sealifebase.ca for	: Eupolymnia nebulosa
# Using www.sealifebase.ca for	: Eurydice affinis
# Using www.sealifebase.ca for	: Eurysyllis tuberculata
# Using www.sealifebase.ca for	: Euspira catena
# Using www.sealifebase.ca for	: Eusyllis blomstrandi
# Using www.fishbase.de for	: Eutelichthys leptochirus
# Using www.fishbase.de for	: Euthynnus alletteratus
# Using www.fishbase.de for	: Evermannella balbo
# Using www.fishbase.de for	: Exocoetus obtusirostris
# Using www.sealifebase.ca for	: Exogone dispar
# Using www.sealifebase.ca for	: Exogone naidina
# Using www.fishbase.de for	: Facciolella oxyrhyncha
# Using www.sealifebase.ca for	: Falcidens aequabilis
# Using www.sealifebase.ca for	: Falcidens gutturosus
# Using www.sealifebase.ca for	: Fenestrulina malusii
# Using www.sealifebase.ca for	: Ficopomatus enigmaticus
# Using www.sealifebase.ca for	: Figularia figularis
# Using www.sealifebase.ca for	: Filellum serratum
# Using www.sealifebase.ca for	: Firoloida desmarestia
# Using www.sealifebase.ca for	: Flabelligera diplochaitos
# Using www.sealifebase.ca for	: Flaccisagitta enflata
# Using www.sealifebase.ca for	: Flaccisagitta hexaptera
# Using www.sealifebase.ca for	: Flexopecten glaber
# Using www.sealifebase.ca for	: Fritillaria pellucida
# Using www.sealifebase.ca for	: Funchalia villosa
# Using www.sealifebase.ca for	: Funchalia woodwardi
# Using www.sealifebase.ca for	: Funchalia woodwardi
# Using www.sealifebase.ca for	: Funiculina quadrangularis
# Using www.sealifebase.ca for	: Fustiaria rubescens
# Using www.fishbase.de for	: Gadella maraldi
# Using www.fishbase.de for	: Gadiculus argenteus
# Using www.sealifebase.ca for	: Gadila strangulata
# Using www.fishbase.de for	: Gaidropsarus biscayensis
# Using www.fishbase.de for	: Gaidropsarus mediterraneus
# Using www.fishbase.de for	: Gaidropsarus vulgaris
# Using www.sealifebase.ca for	: Galeodea rugosa
# Using www.fishbase.de for	: Galeorhinus galeus
# Using www.fishbase.de for	: Galeus melastomus
# Using www.sealifebase.ca for	: Galiteuthis armata
# Using www.fishbase.de for	: Gammogobius steinitzi
# Using www.sealifebase.ca for	: Ganonema farinosum
# Using www.sealifebase.ca for	: Gari depressa
# Using www.sealifebase.ca for	: Gari fervensis
# Using www.fishbase.de for	: Gasterosteus aculeatus
# Using www.sealifebase.ca for	: Gastrosaccus sanctus
# Using www.sealifebase.ca for	: Gastrosaccus spinifer
# Using www.sealifebase.ca for	: Geitodoris pusae
# Using www.sealifebase.ca for	: Gelidium pusillum
# Using www.sealifebase.ca for	: Gennadas elegans
# Using www.sealifebase.ca for	: Geryon longipes
# Using www.sealifebase.ca for	: Gibbula magus
# Using www.sealifebase.ca for	: Glandiceps talaboti
# Using www.sealifebase.ca for	: Globicephala melas
# Using www.fishbase.de for	: Glossanodon leioglossus
# Using www.sealifebase.ca for	: Glycera alba
# Using www.sealifebase.ca for	: Glycera rouxi
# Using www.sealifebase.ca for	: Glycera tesselata
# Using www.sealifebase.ca for	: Glycera tridactyla
# Using www.sealifebase.ca for	: Glycera unicornis
# Using www.sealifebase.ca for	: Glycymeris bimaculata
# Using www.sealifebase.ca for	: Glycymeris glycymeris
# Using www.sealifebase.ca for	: Glycymeris insubrica
# Using www.sealifebase.ca for	: Glycymeris nummaria
# Using www.sealifebase.ca for	: Glycymeris pilosa
# Using www.sealifebase.ca for	: Gnathia vorax
# Using www.sealifebase.ca for	: Gnathophausia zoea
# Using www.fishbase.de for	: Gnathophis mystax
# Using www.fishbase.de for	: Gobius ater
# Using www.fishbase.de for	: Gobius auratus
# Using www.fishbase.de for	: Gobius bucchichi
# Using www.fishbase.de for	: Gobius cobitis
# Using www.fishbase.de for	: Gobius cruentatus
# Using www.fishbase.de for	: Gobius fallax
# Using www.fishbase.de for	: Gobius gasteveni
# Using www.fishbase.de for	: Gobius geniporus
# Using www.fishbase.de for	: Gobius kolombatovici
# Using www.fishbase.de for	: Gobius niger
# Using www.fishbase.de for	: Gobius paganellus
# Using www.fishbase.de for	: Gobius roulei
# Using www.fishbase.de for	: Gobius vittatus
# Using www.fishbase.de for	: Gobius xanthocephalus
# Using www.sealifebase.ca for	: Golfingia elongata
# Using www.sealifebase.ca for	: Golfingia margaritacea
# Using www.sealifebase.ca for	: Golfingia vulgaris
# Using www.sealifebase.ca for	: Goneplax rhomboides
# Using www.sealifebase.ca for	: Goniada maculata
# Using www.fishbase.de for	: Gonichthys cocco
# Using www.fishbase.de for	: Gonostoma denudatum
# Using www.fishbase.de for	: Gouania willdenowi
# Using www.sealifebase.ca for	: Gracilaria arcuata
# Using www.sealifebase.ca for	: Gracilechinus acutus
# Using www.sealifebase.ca for	: Grampus griseus
# Using www.sealifebase.ca for	: Grateloupia filicina
# Using www.sealifebase.ca for	: Gregariella petagnae
# Using www.sealifebase.ca for	: Guynia annulata
# Using www.sealifebase.ca for	: Gwynia capsula
# Using www.fishbase.de for	: Gymnammodytes cicerelus
# Using www.fishbase.de for	: Gymnothorax unicolor
# Using www.fishbase.de for	: Gymnura altavela
# Using www.sealifebase.ca for	: Hacelia attenuata
# Using www.sealifebase.ca for	: Halichaetonotus aculifer
# Using www.sealifebase.ca for	: Halichaetonotus decipiens
# Using www.sealifebase.ca for	: Halichaetonotus marivagus
# Using www.sealifebase.ca for	: Halichaetonotus paradoxus
# Using www.sealifebase.ca for	: Halimeda tuna
# Using www.sealifebase.ca for	: Haliotis tuberculata
# Using www.sealifebase.ca for	: Haliphron atlanticus
# Using www.fishbase.de for	: Halobatrachus didactylus
# Using www.sealifebase.ca for	: Halocynthia papillosa
# Using www.sealifebase.ca for	: Haminoea elegans
# Using www.sealifebase.ca for	: Haplopoma impressum
# Using www.sealifebase.ca for	: Haplostylus bacescui
# Using www.sealifebase.ca for	: Haplostylus lobatus
# Using www.sealifebase.ca for	: Haplostylus normani
# Using www.sealifebase.ca for	: Haplosyllis spongicola
# Using www.sealifebase.ca for	: Helgicirrha schulzei
# Using www.fishbase.de for	: Helicolenus dactylopterus
# Using www.sealifebase.ca for	: Hemimysis lamornae
# Using www.sealifebase.ca for	: Hemimysis margalefi
# Using www.sealifebase.ca for	: Hemimysis speluncola
# Using www.fishbase.de for	: Heptranchias perlo
# Using www.sealifebase.ca for	: Hermodice carunculata
# Using www.sealifebase.ca for	: Hesione pantherina
# Using www.sealifebase.ca for	: Hesione splendida
# Using www.sealifebase.ca for	: Hesionura elongata
# Using www.sealifebase.ca for	: Heteranomia squamula
# Using www.sealifebase.ca for	: Heteromastus filiformis
# Using www.sealifebase.ca for	: Heteromysis norvegica
# Using www.sealifebase.ca for	: Heteroteuthis dispar
# Using www.sealifebase.ca for	: Heteroxenotrichula squamosa
# Using www.fishbase.de for	: Hexanchus griseus
# Using www.fishbase.de for	: Hexanchus nakamurai
# Using www.sealifebase.ca for	: Hexaplex trunculus
# Using www.sealifebase.ca for	: Hiatella arctica
# Using www.fishbase.de for	: Hippocampus guttulatus
# Using www.fishbase.de for	: Hippocampus hippocampus
# Using www.sealifebase.ca for	: Hipponix conicus
# Using www.sealifebase.ca for	: Hippopodius hippopus
# Using www.sealifebase.ca for	: Hippospongia communis
# Using www.fishbase.de for	: Hirundichthys rondeletii
# Using www.sealifebase.ca for	: Histioteuthis bonnellii
# Using www.sealifebase.ca for	: Histioteuthis elongata
# Using www.sealifebase.ca for	: Histioteuthis reversa
# Using www.sealifebase.ca for	: Holothuria forskali
# Using www.sealifebase.ca for	: Holothuria impatiens
# Using www.sealifebase.ca for	: Holothuria poli
# Using www.sealifebase.ca for	: Holothuria sanctori
# Using www.sealifebase.ca for	: Holothuria tubulosa
# Using www.sealifebase.ca for	: Homola barbata
# Using www.sealifebase.ca for	: Hoplangia durotrix
# Using www.fishbase.de for	: Hoplostethus mediterraneus
# Using www.fishbase.de for	: Huso huso
# Using www.sealifebase.ca for	: Hyalinoecia tubicola
# Using www.sealifebase.ca for	: Hyalocylis striata
# Using www.sealifebase.ca for	: Hydroclathrus clathratus
# Using www.sealifebase.ca for	: Hydroides albiceps
# Using www.sealifebase.ca for	: Hydroides elegans
# Using www.sealifebase.ca for	: Hydroides norvegicus
# Using www.sealifebase.ca for	: Hydrophis coggeri
# Using www.sealifebase.ca for	: Hydrophis ornatus
# Using www.sealifebase.ca for	: Hydrophis spiralis
# Using www.fishbase.de for	: Hygophum benoiti
# Using www.fishbase.de for	: Hygophum hygomii
# Using www.fishbase.de for	: Hymenocephalus italicus
# Using www.fishbase.de for	: Hypleurochilus bananensis
# Using www.sealifebase.ca for	: Hypnea musciformis
# Using www.sealifebase.ca for	: Hypnea valentiae
# Using www.fishbase.de for	: Hyporhamphus picarti
# Using www.fishbase.de for	: Hyporthodus haifensis
# Using www.sealifebase.ca for	: Hypselodoris infucata
# Using www.fishbase.de for	: Ichthyococcus ovatus
# Using www.sealifebase.ca for	: Idotea metallica
# Using www.sealifebase.ca for	: Illex coindetii
# Using www.sealifebase.ca for	: Ischnochiton rissoi
# Using www.sealifebase.ca for	: Isidella elongata
# Using www.fishbase.de for	: Isurus paucus
# Using www.sealifebase.ca for	: Janthina janthina
# Using www.sealifebase.ca for	: Janua pagenstecheri
# Using www.sealifebase.ca for	: Jasmineira elegans
# Using www.sealifebase.ca for	: Javania cailleti
# Using www.sealifebase.ca for	: Josephella marenzelleri
# Using www.fishbase.de for	: Kajikia albida
# Using www.fishbase.de for	: Katsuwonus pelamis
# Using www.sealifebase.ca for	: Kellia suborbicularis
# Using www.fishbase.de for	: Knipowitschia caucasica
# Using www.sealifebase.ca for	: Kophobelemnon stelliferum
# Using www.sealifebase.ca for	: Krohnitta subtilis
# Using www.fishbase.de for	: Kyphosus sectatrix
# Using www.sealifebase.ca for	: Labioleanira yhleni
# Using www.fishbase.de for	: Labrus merula
# Using www.fishbase.de for	: Labrus mixtus
# Using www.fishbase.de for	: Labrus viridis
# Using www.sealifebase.ca for	: Laevicardium crassum
# Using www.fishbase.de for	: Lagocephalus lagocephalus
# Using www.fishbase.de for	: Lamna nasus
# Using www.fishbase.de for	: Lampanyctus crocodilus
# Using www.fishbase.de for	: Lampanyctus pusillus
# Using www.fishbase.de for	: Lampris guttatus
# Using www.sealifebase.ca for	: Lanice conchilega
# Using www.sealifebase.ca for	: Laonice cirrata
# Using www.fishbase.de for	: Lappanella fasciata
# Using www.sealifebase.ca for	: Laurencia obtusa
# Using www.sealifebase.ca for	: Leander tenuicornis
# Using www.sealifebase.ca for	: Leiopathes glaberrima
# Using www.sealifebase.ca for	: Lekanesphaera monodi
# Using www.sealifebase.ca for	: Lensia campanella
# Using www.sealifebase.ca for	: Lensia conoidea
# Using www.sealifebase.ca for	: Lensia fowleri
# Using www.sealifebase.ca for	: Lensia subtilis
# Using www.sealifebase.ca for	: Leocrates claparedii
# Using www.fishbase.de for	: Lepadogaster candolii
# Using www.fishbase.de for	: Lepadogaster lepadogaster
# Using www.sealifebase.ca for	: Lepas anatifera
# Using www.fishbase.de for	: Lepidion lepidion
# Using www.sealifebase.ca for	: Lepidochelys kempii
# Using www.sealifebase.ca for	: Lepidonotus carinulatus
# Using www.sealifebase.ca for	: Lepidonotus tenuisetosus
# Using www.sealifebase.ca for	: Lepidopleurus cajetanus
# Using www.fishbase.de for	: Lepidopus caudatus
# Using www.fishbase.de for	: Lepidorhombus boscii
# Using www.fishbase.de for	: Lepidotrigla cavillone
# Using www.fishbase.de for	: Lepidotrigla dieuzeidei
# Using www.sealifebase.ca for	: Leptochelia savignyi
# Using www.sealifebase.ca for	: Leptometra celtica
# Using www.sealifebase.ca for	: Leptometra phalangium
# Using www.sealifebase.ca for	: Leptomysis buergii
# Using www.sealifebase.ca for	: Leptomysis gracilis
# Using www.sealifebase.ca for	: Leptomysis heterophila
# Using www.sealifebase.ca for	: Leptomysis lingvura
# Using www.sealifebase.ca for	: Leptomysis mediterranea
# Using www.sealifebase.ca for	: Leptomysis megalops
# Using www.sealifebase.ca for	: Leptopsammia pruvoti
# Using www.sealifebase.ca for	: Leptosynapta minuta
# Using www.sealifebase.ca for	: Lernaeodiscus ingolfi
# Using www.fishbase.de for	: Lestidiops jayakari
# Using www.fishbase.de for	: Lestidiops sphyrenoides
# Using www.fishbase.de for	: Lestidium atlanticum
# Using www.fishbase.de for	: Lesueurigobius friesii
# Using www.fishbase.de for	: Lesueurigobius sanzi
# Using www.fishbase.de for	: Lesueurigobius suerii
# Using www.sealifebase.ca for	: Leucetta primigenia
# Using www.sealifebase.ca for	: Leuconia pumila
# Using www.fishbase.de for	: Leucoraja circularis
# Using www.fishbase.de for	: Leucoraja fullonica
# Using www.fishbase.de for	: Leucoraja melitensis
# Using www.fishbase.de for	: Leucoraja naevus
# Using www.sealifebase.ca for	: Leucosolenia blanca
# Using www.sealifebase.ca for	: Leucosolenia canariensis
# Using www.sealifebase.ca for	: Leucosolenia clathrus
# Using www.sealifebase.ca for	: Levinsenia gracilis
# Using www.sealifebase.ca for	: Lichenopora radiata
# Using www.fishbase.de for	: Lichia amia
# Using www.sealifebase.ca for	: Ligia italica
# Using www.sealifebase.ca for	: Lima hians
# Using www.sealifebase.ca for	: Lima inflata
# Using www.sealifebase.ca for	: Lima lima
# Using www.sealifebase.ca for	: Limacina trochiformis
# Using www.sealifebase.ca for	: Limatula subauriculata
# Using www.sealifebase.ca for	: Linatella caudata
# Using www.sealifebase.ca for	: Liocarcinus corrugatus
# Using www.sealifebase.ca for	: Liocarcinus navigator
# Using www.sealifebase.ca for	: Liocarcinus vernalis
# Using www.fishbase.de for	: Lipophrys pholis
# Using www.fishbase.de for	: Lipophrys trigloides
# Using www.sealifebase.ca for	: Liriope tetraphylla
# Using www.sealifebase.ca for	: Lissodendoryx isodictyalis
# Using www.fishbase.de for	: Lithognathus mormyrus
# Using www.sealifebase.ca for	: Lithophaga lithophaga
# Using www.fishbase.de for	: Liza aurata
# Using www.fishbase.de for	: Liza ramada
# Using www.fishbase.de for	: Liza saliens
# Using www.fishbase.de for	: Lobianchia dofleini
# Using www.fishbase.de for	: Lobianchia gemellarii
# Using www.fishbase.de for	: Lobotes surinamensis
# Using www.sealifebase.ca for	: Loimia medusa
# Using www.sealifebase.ca for	: Loligo forbesii
# Using www.sealifebase.ca for	: Loligo media
# Using www.sealifebase.ca for	: Loligo vulgaris
# Using www.sealifebase.ca for	: Lophelia pertusa
# Using www.fishbase.de for	: Lophius budegassa
# Using www.fishbase.de for	: Lophius piscatorius
# Using www.sealifebase.ca for	: Lophogaster typicus
# Using www.fishbase.de for	: Lophotus lacepede
# Using www.sealifebase.ca for	: Loripes lacteus
# Using www.sealifebase.ca for	: Loripes lucinalis
# Using www.sealifebase.ca for	: Loxosomella atkinsae
# Using www.sealifebase.ca for	: Lucifer typus
# Using www.sealifebase.ca for	: Lucinella divaricata
# Using www.sealifebase.ca for	: Lumbrineris cingulata
# Using www.sealifebase.ca for	: Lumbrineris latreilli
# Using www.sealifebase.ca for	: Lurifax vitreus
# Using www.sealifebase.ca for	: Lutraria angustior
# Using www.fishbase.de for	: Luvarus imperialis
# Using www.sealifebase.ca for	: Lyrodus pedicellatus
# Using www.sealifebase.ca for	: Lysidice collaris
# Using www.sealifebase.ca for	: Lysidice ninetta
# Using www.sealifebase.ca for	: Lysmata seticaudata
# Using www.sealifebase.ca for	: Macoma balthica
# Using www.sealifebase.ca for	: Macrodasys caudatus
# Using www.sealifebase.ca for	: Macropipus tuberculatus
# Using www.sealifebase.ca for	: Macropodia longirostris
# Using www.fishbase.de for	: Macroramphosus scolopax
# Using www.sealifebase.ca for	: Macrotritopus defilippi
# Using www.sealifebase.ca for	: Mactra glabrata
# Using www.sealifebase.ca for	: Mactra stultorum
# Using www.sealifebase.ca for	: Madracis pharensis
# Using www.sealifebase.ca for	: Madrepora oculata
# Using www.sealifebase.ca for	: Maja goltziana
# Using www.sealifebase.ca for	: Maja squinado
# Using www.fishbase.de for	: Makaira nigricans
# Using www.sealifebase.ca for	: Maldane glebifex
# Using www.sealifebase.ca for	: Maldane sarsi
# Using www.sealifebase.ca for	: Malleus regula
# Using www.sealifebase.ca for	: Manupecten pesfelis
# Using www.sealifebase.ca for	: Marphysa bellii
# Using www.sealifebase.ca for	: Marphysa sanguinea
# Using www.sealifebase.ca for	: Marthasterias glacialis
# Using www.sealifebase.ca for	: Mastobranchus trinchesii
# Using www.fishbase.de for	: Maurolicus muelleri
# Using www.sealifebase.ca for	: Megabalanus tintinnabulum
# Using www.sealifebase.ca for	: Megalomma vesiculosum
# Using www.sealifebase.ca for	: Megaptera novaeangliae
# Using www.sealifebase.ca for	: Megathiris detruncata
# Using www.sealifebase.ca for	: Megerlia truncata
# Using www.fishbase.de for	: Melanostigma atlanticum
# Using www.sealifebase.ca for	: Melicertus kerathurus
# Using www.sealifebase.ca for	: Melinna cristata
# Using www.sealifebase.ca for	: Melinna palmata
# Using www.sealifebase.ca for	: Membranipora tenuis
# Using www.sealifebase.ca for	: Menaethius monoceros
# Using www.fishbase.de for	: Merluccius merluccius
# Using www.sealifebase.ca for	: Mesochaetopterus sagittarius
# Using www.sealifebase.ca for	: Mesodasys adenotubulatus
# Using www.sealifebase.ca for	: Mesodasys laticaudatus
# Using www.sealifebase.ca for	: Mesoplodon densirostris
# Using www.sealifebase.ca for	: Mesopodopsis slabberi
# Using www.sealifebase.ca for	: Mesosagitta minima
# Using www.sealifebase.ca for	: Mesothuria intestinalis
# Using www.sealifebase.ca for	: Metapenaeopsis aegyptia
# Using www.sealifebase.ca for	: Metavermilia multicristata
# Using www.fishbase.de for	: Microchirus azevia
# Using www.fishbase.de for	: Microchirus boscanion
# Using www.fishbase.de for	: Microchirus ocellatus
# Using www.fishbase.de for	: Microchirus variegatus
# Using www.sealifebase.ca for	: Microcosmus claudicans
# Using www.sealifebase.ca for	: Microcosmus sabatieri
# Using www.sealifebase.ca for	: Microcosmus savignyi
# Using www.sealifebase.ca for	: Microcosmus vulgaris
# Using www.fishbase.de for	: Microlipophrys adriaticus
# Using www.fishbase.de for	: Microlipophrys canevae
# Using www.fishbase.de for	: Microlipophrys dalmatinus
# Using www.fishbase.de for	: Microlipophrys nigriceps
# Using www.fishbase.de for	: Micromesistius poutassou
# Using www.sealifebase.ca for	: Microporella ciliata
# Using www.fishbase.de for	: Microstoma microstoma
# Using www.fishbase.de for	: Millerigobius macrocephalus
# Using www.sealifebase.ca for	: Mimachlamys varia
# Using www.fishbase.de for	: Minyichthys sentus
# Using www.fishbase.de for	: Mobula mobular
# Using www.sealifebase.ca for	: Modeeria rotunda
# Using www.sealifebase.ca for	: Modiolus adriaticus
# Using www.sealifebase.ca for	: Modiolus barbatus
# Using www.fishbase.de for	: Mola mola
# Using www.fishbase.de for	: Molva dypterygia
# Using www.fishbase.de for	: Molva macrophthalma
# Using www.sealifebase.ca for	: Monachus monachus
# Using www.fishbase.de for	: Monochirus hispidus
# Using www.sealifebase.ca for	: Monophorus perversus
# Using www.fishbase.de for	: Mora moro
# Using www.sealifebase.ca for	: Muggiaea atlantica
# Using www.fishbase.de for	: Mugil cephalus
# Using www.fishbase.de for	: Mullus barbatus
# Using www.fishbase.de for	: Mullus surmuletus
# Using www.sealifebase.ca for	: Munida intermedia
# Using www.sealifebase.ca for	: Munidopsis curvirostra
# Using www.sealifebase.ca for	: Munidopsis serricornis
# Using www.fishbase.de for	: Muraena helena
# Using www.sealifebase.ca for	: Musculus costulatus
# Using www.sealifebase.ca for	: Musculus discors
# Using www.fishbase.de for	: Mustelus asterias
# Using www.fishbase.de for	: Mustelus mustelus
# Using www.fishbase.de for	: Mustelus punctulatus
# Using www.fishbase.de for	: Mycteroperca rubra
# Using www.fishbase.de for	: Myctophum punctatum
# Using www.fishbase.de for	: Myliobatis aquila
# Using www.sealifebase.ca for	: Myrtea spinifera
# Using www.sealifebase.ca for	: Mysia undata
# Using www.sealifebase.ca for	: Mysideis parva
# Using www.sealifebase.ca for	: Mysidella typica
# Using www.sealifebase.ca for	: Mysidopsis angusta
# Using www.sealifebase.ca for	: Mysidopsis gibbosa
# Using www.sealifebase.ca for	: Mytilus edulis
# Using www.sealifebase.ca for	: Mytilus galloprovincialis
# Using www.sealifebase.ca for	: Myxicola infundibulum
# Using www.fishbase.de for	: Nansenia oblita
# Using www.sealifebase.ca for	: Nassarius arcularia
# Using www.sealifebase.ca for	: Nassarius incrassatus
# Using www.sealifebase.ca for	: Nassarius mutabilis
# Using www.sealifebase.ca for	: Natatolana borealis
# Using www.sealifebase.ca for	: Natatolana neglecta
# Using www.fishbase.de for	: Naucrates ductor
# Using www.sealifebase.ca for	: Neanthes caudata
# Using www.sealifebase.ca for	: Neanthes kerguelensis
# Using www.sealifebase.ca for	: Nematonereis hebes
# Using www.fishbase.de for	: Nemichthys scolopaceus
# Using www.sealifebase.ca for	: Neodexiospira pseudocorrugata
# Using www.fishbase.de for	: Neogobius melanostomus
# Using www.sealifebase.ca for	: Neopycnodonte cochlear
# Using www.sealifebase.ca for	: Neorossia caroli
# Using www.sealifebase.ca for	: Nephasoma abyssorum
# Using www.sealifebase.ca for	: Nephasoma confusum
# Using www.sealifebase.ca for	: Nephasoma constrictum
# Using www.sealifebase.ca for	: Nephasoma rimicola
# Using www.sealifebase.ca for	: Nephrops norvegicus
# Using www.sealifebase.ca for	: Nephtys hystricis
# Using www.sealifebase.ca for	: Nereis pelagica
# Using www.fishbase.de for	: Nerophis maculatus
# Using www.fishbase.de for	: Nerophis ophidion
# Using www.fishbase.de for	: Nettastoma melanurum
# Using www.fishbase.de for	: Nezumia aequalis
# Using www.fishbase.de for	: Nezumia sclerorhynchus
# Using www.sealifebase.ca for	: Nicolea zostericola
# Using www.fishbase.de for	: Notacanthus bonaparte
# Using www.sealifebase.ca for	: Nothria conchylega
# Using www.sealifebase.ca for	: Notomastus latericeus
# Using www.fishbase.de for	: Notoscopelus bolini
# Using www.fishbase.de for	: Notoscopelus elongatus
# Using www.sealifebase.ca for	: Nucula hanleyi
# Using www.sealifebase.ca for	: Nucula nucleus
# Using www.sealifebase.ca for	: Nucula sulcata
# Using www.sealifebase.ca for	: Nucula turgida
# Using www.fishbase.de for	: Oblada melanura
# Using www.sealifebase.ca for	: Ocnus planci
# Using www.sealifebase.ca for	: Octophialucium funerarium
# Using www.sealifebase.ca for	: Octopoteuthis sicula
# Using www.sealifebase.ca for	: Octopus salutii
# Using www.sealifebase.ca for	: Octopus vulgaris
# Using www.sealifebase.ca for	: Oculina patagonica
# Using www.sealifebase.ca for	: Ocypode cursor
# Using www.fishbase.de for	: Odondebuenia balearica
# Using www.fishbase.de for	: Odontaspis ferox
# Using www.sealifebase.ca for	: Odostomella doliolum
# Using www.sealifebase.ca for	: Odostomia nitens
# Using www.fishbase.de for	: Oedalechilus labeo
# Using www.sealifebase.ca for	: Oikopleura albicans
# Using www.sealifebase.ca for	: Oikopleura cophocerca
# Using www.sealifebase.ca for	: Oikopleura dioica
# Using www.sealifebase.ca for	: Oikopleura longicauda
# Using www.sealifebase.ca for	: Oikopleura parva
# Using www.sealifebase.ca for	: Oikopleura rufescens
# Using www.sealifebase.ca for	: Ommastrephes bartramii
# Using www.sealifebase.ca for	: Onuphis eremita
# Using www.sealifebase.ca for	: Onychoteuthis banksii
# Using www.sealifebase.ca for	: Ophelina acuminata
# Using www.fishbase.de for	: Ophichthus rufus
# Using www.sealifebase.ca for	: Ophidiaster ophidianus
# Using www.fishbase.de for	: Ophidion barbatum
# Using www.fishbase.de for	: Ophidion rochei
# Using www.sealifebase.ca for	: Ophiomyxa pentagona
# Using www.sealifebase.ca for	: Ophiopsila annulosa
# Using www.sealifebase.ca for	: Ophiopsila aranea
# Using www.fishbase.de for	: Ophisurus serpens
# Using www.sealifebase.ca for	: Ophiura grubei
# Using www.sealifebase.ca for	: Orcinus orca
# Using www.fishbase.de for	: Orcynopsis unicolor
# Using www.sealifebase.ca for	: Ornithoteuthis antillarum
# Using www.sealifebase.ca for	: Oscarella lobularis
# Using www.sealifebase.ca for	: Ostrea capsa
# Using www.sealifebase.ca for	: Ostrea edulis
# Using www.sealifebase.ca for	: Owenia fusiformis
# Using www.sealifebase.ca for	: Oxynoe viridis
# Using www.fishbase.de for	: Oxynotus centrina
# Using www.sealifebase.ca for	: Pachygrapsus marmoratus
# Using www.sealifebase.ca for	: Padina gymnospora
# Using www.sealifebase.ca for	: Padina pavonica
# Using www.fishbase.de for	: Pagellus acarne
# Using www.fishbase.de for	: Pagellus bogaraveo
# Using www.fishbase.de for	: Pagellus erythrinus
# Using www.fishbase.de for	: Pagrus auriga
# Using www.fishbase.de for	: Pagrus caeruleostictus
# Using www.fishbase.de for	: Pagrus pagrus
# Using www.sealifebase.ca for	: Paguristes eremita
# Using www.sealifebase.ca for	: Paguristes syrtensis
# Using www.sealifebase.ca for	: Palaemon adspersus
# ...
# Using www.fishbase.de for	: Pseudocaranx dentex
# Using www.sealifebase.ca for	: Pseudopolydora antennata
# Using www.sealifebase.ca for	: Pseudorca crassidens
# Using www.sealifebase.ca for	: Pseudosagitta lyra
# Using www.sealifebase.ca for	: Pseudostomella etrusca
# Using www.sealifebase.ca for	: Pseudostomella roscovita
# Using www.sealifebase.ca for	: Pseudothyone raphanus
# Using www.sealifebase.ca for	: Pteria hirundo
# Using www.sealifebase.ca for	: Pterocladiella capillacea
# Using www.sealifebase.ca for	: Pteroctopus tetracirrhus
# Using www.fishbase.de for	: Pteroplatytrygon violacea
# Using www.sealifebase.ca for	: Pterygioteuthis giardi
# Using www.sealifebase.ca for	: Ptychostomella tyrrhenica
# Using www.sealifebase.ca for	: Puellina gattyae
# Using www.sealifebase.ca for	: Puellina innominata
# Using www.sealifebase.ca for	: Puellina radiata
# Using www.sealifebase.ca for	: Pyroteuthis margaritifera
# Using www.sealifebase.ca for	: Pyura squamulosa
# Using www.sealifebase.ca for	: Pyura tessellata
# Using www.fishbase.de for	: Raja africana
# Using www.fishbase.de for	: Raja asterias
# Using www.fishbase.de for	: Raja brachyura
# Using www.fishbase.de for	: Raja clavata
# Using www.fishbase.de for	: Raja miraletus
# Using www.fishbase.de for	: Raja montagui
# Using www.fishbase.de for	: Raja polystigma
# Using www.fishbase.de for	: Raja radula
# Using www.fishbase.de for	: Raja rondeleti
# Using www.fishbase.de for	: Raja undulata
# Using www.sealifebase.ca for	: Ranella olearius
# Using www.fishbase.de for	: Ranzania laevis
# Using www.sealifebase.ca for	: Rapana venosa
# Using www.fishbase.de for	: Regalecus glesne
# Using www.fishbase.de for	: Remora brachyptera
# Using www.fishbase.de for	: Remora osteochir
# Using www.fishbase.de for	: Remora remora
# Using www.sealifebase.ca for	: Reptadeonella violacea
# Using www.sealifebase.ca for	: Rhinoclavis kochi
# Using www.fishbase.de for	: Rhinoptera marginata
# Using www.sealifebase.ca for	: Rhodine gracilior
# Using www.sealifebase.ca for	: Rhodosoma turcicum
# Using www.sealifebase.ca for	: Rocinela dumerilii
# Using www.sealifebase.ca for	: Rondeletiola minor
# Using www.sealifebase.ca for	: Rosacea cymbiformis
# Using www.sealifebase.ca for	: Rosacea plicata
# Using www.sealifebase.ca for	: Rossia macrosoma
# Using www.fishbase.de for	: Rostroraja alba
# Using www.sealifebase.ca for	: Royella sinon
# Using www.sealifebase.ca for	: Ruditapes decussatus
# Using www.fishbase.de for	: Ruvettus pretiosus
# Using www.fishbase.de for	: Salaria basilisca
# Using www.fishbase.de for	: Salaria pavo
# Using www.sealifebase.ca for	: Salmacina dysteri
# Using www.fishbase.de for	: Salmo salar
# Using www.fishbase.de for	: Salmo trutta
# Using www.sealifebase.ca for	: Salpa fusiformis
# Using www.sealifebase.ca for	: Salpa maxima
# Using www.sealifebase.ca for	: Salvatoria clavata
# Using www.sealifebase.ca for	: Salvatoria limbata
# Using www.fishbase.de for	: Sarda sarda
# Using www.fishbase.de for	: Sardina pilchardus
# Using www.fishbase.de for	: Sardinella aurita
# Using www.fishbase.de for	: Sardinella maderensis
# Using www.sealifebase.ca for	: Sargassum vulgare
# Using www.fishbase.de for	: Sarpa salpa
# Using www.sealifebase.ca for	: Savignyella lafontii
# Using www.sealifebase.ca for	: Scaeurgus unicirrhus
# Using www.sealifebase.ca for	: Scandia gigas
# Using www.sealifebase.ca for	: Scaphander punctostriatus
# Using www.sealifebase.ca for	: Scapharca cornea
# Using www.fishbase.de for	: Scartella cristata
# Using www.fishbase.de for	: Schedophilus medusophagus
# Using www.fishbase.de for	: Schedophilus ovalis
# Using www.sealifebase.ca for	: Schizomavella discoidea
# Using www.sealifebase.ca for	: Schizoporella errata
# Using www.sealifebase.ca for	: Schizoporella unicornis
# Using www.fishbase.de for	: Sciaena umbra
# Using www.sealifebase.ca for	: Scolanthus callimorphus
# Using www.sealifebase.ca for	: Scolelepis squamata
# Using www.sealifebase.ca for	: Scoletoma impatiens
# Using www.fishbase.de for	: Scomber colias
# Using www.fishbase.de for	: Scomber scombrus
# Using www.fishbase.de for	: Scomberesox saurus
# Using www.fishbase.de for	: Scophthalmus maximus
# Using www.fishbase.de for	: Scophthalmus rhombus
# Using www.fishbase.de for	: Scorpaena elongata
# Using www.fishbase.de for	: Scorpaena loppei
# Using www.fishbase.de for	: Scorpaena maderensis
# Using www.fishbase.de for	: Scorpaena notata
# Using www.fishbase.de for	: Scorpaena porcus
# Using www.fishbase.de for	: Scorpaena scrofa
# Using www.fishbase.de for	: Scorpaenodes arenai
# Using www.sealifebase.ca for	: Scrobicularia plana
# Using www.sealifebase.ca for	: Scrupocellaria bertholetti
# Using www.sealifebase.ca for	: Scrupocellaria scrupea
# Using www.sealifebase.ca for	: Scutopus robustus
# Using www.fishbase.de for	: Scyliorhinus canicula
# Using www.fishbase.de for	: Scyliorhinus stellaris
# Using www.sealifebase.ca for	: Scyllaea pelagica
# Using www.sealifebase.ca for	: Scyllarides latus
# Using www.sealifebase.ca for	: Scyllarus arctus
# Using www.sealifebase.ca for	: Scyllarus pygmaeus
# Using www.sealifebase.ca for	: Semicassis granulata
# Using www.sealifebase.ca for	: Sepia officinalis
# Using www.sealifebase.ca for	: Sepia orbignyana
# Using www.sealifebase.ca for	: Sepietta neglecta
# Using www.sealifebase.ca for	: Sepietta obscura
# Using www.sealifebase.ca for	: Sepietta oweniana
# Using www.sealifebase.ca for	: Sepiola affinis
# Using www.sealifebase.ca for	: Sepiola aurantiaca
# Using www.sealifebase.ca for	: Sepiola intermedia
# Using www.sealifebase.ca for	: Sepiola ligulata
# Using www.sealifebase.ca for	: Sepiola robusta
# Using www.sealifebase.ca for	: Sergestes arcticus
# Using www.sealifebase.ca for	: Sergestes atlanticus
# Using www.sealifebase.ca for	: Sergestes henseni
# Using www.sealifebase.ca for	: Sergia japonica
# Using www.sealifebase.ca for	: Sergia robusta
# Using www.sealifebase.ca for	: Sergia splendens
# Using www.sealifebase.ca for	: Seriocarpa rhizoides
# Using www.fishbase.de for	: Seriola dumerili
# Using www.sealifebase.ca for	: Serpula vermicularis
# Using www.fishbase.de for	: Serranus atricauda
# Using www.fishbase.de for	: Serranus cabrilla
# Using www.fishbase.de for	: Serranus hepatus
# Using www.fishbase.de for	: Serranus scriba
# Using www.sealifebase.ca for	: Serratosagitta serratodentata
# Using www.fishbase.de for	: Serrivomer lanceolatoides
# Using www.sealifebase.ca for	: Sicyonia carinata
# Using www.sealifebase.ca for	: Sigambra parva
# Using www.sealifebase.ca for	: Sigambra tentaculata
# Using www.fishbase.de for	: Sigmops elongatus
# Using www.sealifebase.ca for	: Siriella clausi
# Using www.sealifebase.ca for	: Siriella jaltensis
# Using www.sealifebase.ca for	: Siriella norvegica
# Using www.sealifebase.ca for	: Siriella thompsonii
# Using www.sealifebase.ca for	: Smittoidea reticulata
# Using www.sealifebase.ca for	: Soestia zonaria
# Using www.fishbase.de for	: Solea solea
# Using www.sealifebase.ca for	: Solecurtus strigilatus
# Using www.sealifebase.ca for	: Solenocera membranacea
# Using www.sealifebase.ca for	: Solmundella bitentaculata
# Using www.fishbase.de for	: Somniosus rostratus
# Using www.fishbase.de for	: Sparisoma cretense
# Using www.fishbase.de for	: Sparus aurata
# Using www.sealifebase.ca for	: Sphaerechinus granularis
# Using www.sealifebase.ca for	: Sphaeroma serratum
# Using www.sealifebase.ca for	: Sphaeroma walkeri
# Using www.sealifebase.ca for	: Sphaerosyllis capensis
# Using www.sealifebase.ca for	: Sphaerosyllis pirifera
# Using www.sealifebase.ca for	: Sphaerosyllis taylori
# Using www.fishbase.de for	: Sphyraena sphyraena
# Using www.fishbase.de for	: Sphyrna lewini
# Using www.fishbase.de for	: Sphyrna tudes
# Using www.fishbase.de for	: Sphyrna zygaena
# Using www.fishbase.de for	: Spicara maena
# Using www.fishbase.de for	: Spicara smaris
# Using www.sealifebase.ca for	: Spiochaetopterus costarum
# Using www.sealifebase.ca for	: Spirastrella cunctatrix
# Using www.sealifebase.ca for	: Spirobranchus tetraceros
# Using www.fishbase.de for	: Spondyliosoma cantharus
# Using www.sealifebase.ca for	: Spondylus gaederopus
# Using www.sealifebase.ca for	: Spondylus spinosus
# Using www.sealifebase.ca for	: Spongia agaricina
# Using www.sealifebase.ca for	: Spongia officinalis
# Using www.fishbase.de for	: Sprattus sprattus
# Using www.fishbase.de for	: Squalus acanthias
# Using www.fishbase.de for	: Squalus blainville
# Using www.fishbase.de for	: Squatina squatina
# Using www.sealifebase.ca for	: Squilla mantis
# Using www.sealifebase.ca for	: Stegosoma magnum
# Using www.sealifebase.ca for	: Stelletta grubii
# Using www.sealifebase.ca for	: Stenella coeruleoalba
# Using www.sealifebase.ca for	: Steno bredanensis
# Using www.sealifebase.ca for	: Stenocyathus vermiformis
# Using www.sealifebase.ca for	: Sternaspis scutata
# Using www.sealifebase.ca for	: Sthenelais boa
# Using www.sealifebase.ca for	: Sthenoteuthis pteropus
# Using www.fishbase.de for	: Stomias boa
# Using www.sealifebase.ca for	: Stramonita haemastoma
# Using www.sealifebase.ca for	: Striarca lactea
# Using www.fishbase.de for	: Stromateus fiatola
# Using www.sealifebase.ca for	: Styela canopus
# Using www.sealifebase.ca for	: Styela plicata
# Using www.sealifebase.ca for	: Styliola subula
# Using www.sealifebase.ca for	: Suberites domuncula
# Using www.fishbase.de for	: Sudis hyalina
# Using www.sealifebase.ca for	: Sulculeolaria biloba
# Using www.sealifebase.ca for	: Sulculeolaria chuni
# Using www.sealifebase.ca for	: Sulculeolaria quadrivalvis
# Using www.sealifebase.ca for	: Syllis armillaris
# Using www.sealifebase.ca for	: Syllis cornuta
# Using www.sealifebase.ca for	: Syllis gracilis
# Using www.sealifebase.ca for	: Syllis variegata
# Using www.fishbase.de for	: Symbolophorus veranyi
# Using www.fishbase.de for	: Symphodus bailloni
# Using www.fishbase.de for	: Symphodus cinereus
# Using www.fishbase.de for	: Symphodus doderleini
# Using www.fishbase.de for	: Symphodus mediterraneus
# Using www.fishbase.de for	: Symphodus melanocercus
# Using www.fishbase.de for	: Symphodus melops
# Using www.fishbase.de for	: Symphodus ocellatus
# Using www.fishbase.de for	: Symphodus roissali
# Using www.fishbase.de for	: Symphodus rostratus
# Using www.fishbase.de for	: Symphodus tinca
# Using www.fishbase.de for	: Symphurus nigrescens
# Using www.sealifebase.ca for	: Synalpheus tumidomanus
# Using www.fishbase.de for	: Synapturichthys kleinii
# Using www.fishbase.de for	: Synchiropus phaeton
# Using www.fishbase.de for	: Syngnathus abaster
# Using www.fishbase.de for	: Syngnathus acus
# Using www.fishbase.de for	: Syngnathus phlegon
# Using www.fishbase.de for	: Syngnathus typhle
# Using www.sealifebase.ca for	: Synisoma capito
# Using www.sealifebase.ca for	: Synnotum aegyptiacum
# Using www.fishbase.de for	: Synodus saurus
# Using www.sealifebase.ca for	: Syphonota geographica
# Using www.fishbase.de for	: Taeniura grabata
# Using www.sealifebase.ca for	: Talochlamys multistriata
# Using www.sealifebase.ca for	: Tanais dulongii
# Using www.sealifebase.ca for	: Taningia danae
# Using www.sealifebase.ca for	: Tellina donacina
# Using www.sealifebase.ca for	: Tellina tenuis
# Using www.sealifebase.ca for	: Telmatactis cricoides
# Using www.sealifebase.ca for	: Telmatactis forskalii
# Using www.sealifebase.ca for	: Terebellides stroemii
# Using www.fishbase.de for	: Tetragonurus cuvieri
# Using www.sealifebase.ca for	: Tetranchyroderma cirrophorum
# Using www.sealifebase.ca for	: Tetranchyroderma heterotubulatum
# Using www.sealifebase.ca for	: Tetranchyroderma hirtum
# Using www.sealifebase.ca for	: Tetranchyroderma megastomum
# Using www.sealifebase.ca for	: Tetranchyroderma papii
# Using www.sealifebase.ca for	: Tetranchyroderma polyprobolostomum
# Using www.sealifebase.ca for	: Tetranchyroderma quadritentaculatum
# Using www.sealifebase.ca for	: Tetranchyroderma thysanophorum
# Using www.sealifebase.ca for	: Tetraplatia volitans
# Using www.fishbase.de for	: Tetrapturus belone
# Using www.fishbase.de for	: Tetrapturus georgii
# Using www.fishbase.de for	: Thalassoma pavo
# Using www.sealifebase.ca for	: Thalia democratica
# Using www.sealifebase.ca for	: Thaumastoderma mediterraneum
# Using www.sealifebase.ca for	: Thaumastoderma ramuliferum
# Using www.sealifebase.ca for	: Thelepus setosus
# Using www.sealifebase.ca for	: Thetys vagina
# Using www.fishbase.de for	: Thunnus alalunga
# Using www.fishbase.de for	: Thunnus thynnus
# Using www.sealifebase.ca for	: Thyone fusus
# Using www.sealifebase.ca for	: Thysanocardia catharinae
# Using www.sealifebase.ca for	: Thysanoteuthis rhombus
# Using www.sealifebase.ca for	: Timarete anchylochaeta
# Using www.sealifebase.ca for	: Timarete filigera
# Using www.sealifebase.ca for	: Todarodes sagittatus
# Using www.sealifebase.ca for	: Todaropsis eblanae
# Using www.fishbase.de for	: Torpedo marmorata
# Using www.fishbase.de for	: Torpedo nobiliana
# Using www.fishbase.de for	: Torpedo torpedo
# Using www.fishbase.de for	: Torquigener flavimaculosus
# Using www.fishbase.de for	: Trachinotus ovatus
# Using www.fishbase.de for	: Trachinus araneus
# Using www.fishbase.de for	: Trachinus draco
# Using www.fishbase.de for	: Trachinus radiatus
# Using www.fishbase.de for	: Trachipterus trachypterus
# Using www.fishbase.de for	: Trachurus mediterraneus
# Using www.fishbase.de for	: Trachurus picturatus
# Using www.fishbase.de for	: Trachurus trachurus
# Using www.fishbase.de for	: Trachyrincus scabrus
# Using www.sealifebase.ca for	: Trachysalambria curvirostris
# Using www.sealifebase.ca for	: Tremoctopus violaceus
# Using www.fishbase.de for	: Trichiurus lepturus
# Using www.sealifebase.ca for	: Trichobranchus glacialis
# Using www.fishbase.de for	: Trigla lyra
# Using www.fishbase.de for	: Trigloporus lastoviza
# Using www.fishbase.de for	: Tripterygion delaisi
# Using www.fishbase.de for	: Tripterygion tartessicum
# Using www.fishbase.de for	: Tripterygion tripteronotum
# Using www.sealifebase.ca for	: Truncatella subcylindrica
# Using www.sealifebase.ca for	: Trypanosyllis gigantea
# Using www.sealifebase.ca for	: Trypanosyllis zebra
# Using www.sealifebase.ca for	: Trypetesa lampas
# Using www.sealifebase.ca for	: Turbanella bocqueti
# Using www.sealifebase.ca for	: Turbanella cornuta
# Using www.sealifebase.ca for	: Turbonilla amoena
# Using www.sealifebase.ca for	: Turritella communis
# Using www.sealifebase.ca for	: Turritopsis nutricula
# Using www.sealifebase.ca for	: Tursiops truncatus
# Using www.fishbase.de for	: Tylosurus acus
# Using www.fishbase.de for	: Tylosurus choram
# Using www.sealifebase.ca for	: Typosyllis hyalina
# Using www.sealifebase.ca for	: Ulva clathrata
# Using www.sealifebase.ca for	: Ulva intestinalis
# Using www.sealifebase.ca for	: Ulva lactuca
# Using www.sealifebase.ca for	: Ulva rigida
# Using www.sealifebase.ca for	: Umbraculum umbraculum
# Using www.fishbase.de for	: Umbrina canariensis
# Using www.fishbase.de for	: Umbrina cirrosa
# Using www.fishbase.de for	: Umbrina ronchus
# Using www.fishbase.de for	: Upeneus pori
# Using www.sealifebase.ca for	: Upogebia tipica
# Using www.fishbase.de for	: Uranoscopus scaber
# Using www.sealifebase.ca for	: Urodasys viviparus
# Using www.fishbase.de for	: Valenciennellus tripunctulatus
# Using www.sealifebase.ca for	: Valonia utricularis
# Using www.sealifebase.ca for	: Vampyroteuthis infernalis
# Using www.fishbase.de for	: Vanneaugobius pruvoti
# Using www.sealifebase.ca for	: Venerupis corrugata
# Using www.sealifebase.ca for	: Venus verrucosa
# Using www.sealifebase.ca for	: Veretillum cynomorium
# Using www.fishbase.de for	: Vinciguerria attenuata
# Using www.fishbase.de for	: Vinciguerria poweriae
# Using www.sealifebase.ca for	: Virgularia mirabilis
# Using www.sealifebase.ca for	: Vitreledonella richardi
# Using www.sealifebase.ca for	: Vogtia pentacantha
# Using www.sealifebase.ca for	: Walkeria tuberosa
# Using www.sealifebase.ca for	: Walvisteuthis virilis
# Using www.sealifebase.ca for	: Xenotrichula intermedia
# Using www.sealifebase.ca for	: Xenotrichula punctata
# Using www.fishbase.de for	: Xiphias gladius
# Using www.fishbase.de for	: Xyrichtys novacula
# Using www.sealifebase.ca for	: Zafra vercoi
# Using www.fishbase.de for	: Zebrus zebrus
# Using www.fishbase.de for	: Zeugopterus regius
# Using www.fishbase.de for	: Zeus faber
# Using www.sealifebase.ca for	: Ziphius cavirostris
# Using www.fishbase.de for	: Zosterisessor ophiocephalus
# Using www.fishbase.de for	: Zu cristatus

# %%
dataset
# Out:
#           scientificName commonName                            classification  \
# 0   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 1   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 2   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 3   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 4   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 5   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 6   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 7   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 8   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 9   Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 10  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 11  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 12  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 13  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 14  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 15  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 16  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 17  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 18  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
# 19  Tetraplatia volitans        NaN  Hydrozoa > Narcomedusae > Tetraplatiidae
#
#    etymology environment depthRange usualRange distributionRangeName  \
# 0        NaN     Pelagic    0 - 900        NaN              Tropical
# 1        NaN     Pelagic    0 - 900        NaN              Tropical
# 2        NaN     Pelagic    0 - 900        NaN              Tropical
# 3        NaN     Pelagic    0 - 900        NaN              Tropical
# 4        NaN     Pelagic    0 - 900        NaN              Tropical
# 5        NaN     Pelagic    0 - 900        NaN              Tropical
# 6        NaN     Pelagic    0 - 900        NaN              Tropical
# 7        NaN     Pelagic    0 - 900        NaN              Tropical
# 8        NaN     Pelagic    0 - 900        NaN              Tropical
# 9        NaN     Pelagic    0 - 900        NaN              Tropical
# 10       NaN     Pelagic    0 - 900        NaN              Tropical
# 11       NaN     Pelagic    0 - 900        NaN              Tropical
# 12       NaN     Pelagic    0 - 900        NaN              Tropical
# 13       NaN     Pelagic    0 - 900        NaN              Tropical
# 14       NaN     Pelagic    0 - 900        NaN              Tropical
# 15       NaN     Pelagic    0 - 900        NaN              Tropical
# 16       NaN     Pelagic    0 - 900        NaN              Tropical
# 17       NaN     Pelagic    0 - 900        NaN              Tropical
# 18       NaN     Pelagic    0 - 900        NaN              Tropical
# 19       NaN     Pelagic    0 - 900        NaN              Tropical
#
#    distributionRangeCoordinates  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
#
#                                                                             distributionDescription  \
# 0   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 1   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 2   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 3   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 4   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 5   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 6   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 7   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 8   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 9   Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 10  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 11  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 12  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 13  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 14  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 15  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 16  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 17  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 18  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
# 19  Atlantic, Pacific Oceans and the Mediterranean:  Japan, Chile, Algeria, Brazil, Canada and USA.
#
#    sizeRange maxLength commonLength maxWeight maxAge  \
# 0        NaN       NaN          NaN       NaN    NaN
# 1        NaN       NaN          NaN       NaN    NaN
# 2        NaN       NaN          NaN       NaN    NaN
# 3        NaN       NaN          NaN       NaN    NaN
# 4        NaN       NaN          NaN       NaN    NaN
# 5        NaN       NaN          NaN       NaN    NaN
# 6        NaN       NaN          NaN       NaN    NaN
# 7        NaN       NaN          NaN       NaN    NaN
# 8        NaN       NaN          NaN       NaN    NaN
# 9        NaN       NaN          NaN       NaN    NaN
# 10       NaN       NaN          NaN       NaN    NaN
# 11       NaN       NaN          NaN       NaN    NaN
# 12       NaN       NaN          NaN       NaN    NaN
# 13       NaN       NaN          NaN       NaN    NaN
# 14       NaN       NaN          NaN       NaN    NaN
# 15       NaN       NaN          NaN       NaN    NaN
# 16       NaN       NaN          NaN       NaN    NaN
# 17       NaN       NaN          NaN       NaN    NaN
# 18       NaN       NaN          NaN       NaN    NaN
# 19       NaN       NaN          NaN       NaN    NaN
#
#                                                                                             biologyInfo  \
# 0   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 1   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 2   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 3   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 4   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 5   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 6   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 7   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 8   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 9   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 10  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 11  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 12  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 13  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 14  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 15  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 16  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 17  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 18  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 19  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
#
#                                                                                         lifeAndMateInfo  \
# 0   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 1   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 2   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 3   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 4   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 5   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 6   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 7   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 8   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 9   Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 10  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 11  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 12  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 13  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 14  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 15  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 16  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 17  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 18  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
# 19  Members of the order Narcomedusae include L-form hydroids.  Life cycle:  The zygote develops int...
#
#     redListStatus dorsalSpines dorsalSoftRays analSpines analSoftRays  \
# 0   Not Evaluated          NaN            NaN        NaN          NaN
# 1   Not Evaluated          NaN            NaN        NaN          NaN
# 2   Not Evaluated          NaN            NaN        NaN          NaN
# 3   Not Evaluated          NaN            NaN        NaN          NaN
# 4   Not Evaluated          NaN            NaN        NaN          NaN
# 5   Not Evaluated          NaN            NaN        NaN          NaN
# 6   Not Evaluated          NaN            NaN        NaN          NaN
# 7   Not Evaluated          NaN            NaN        NaN          NaN
# 8   Not Evaluated          NaN            NaN        NaN          NaN
# 9   Not Evaluated          NaN            NaN        NaN          NaN
# 10  Not Evaluated          NaN            NaN        NaN          NaN
# 11  Not Evaluated          NaN            NaN        NaN          NaN
# 12  Not Evaluated          NaN            NaN        NaN          NaN
# 13  Not Evaluated          NaN            NaN        NaN          NaN
# 14  Not Evaluated          NaN            NaN        NaN          NaN
# 15  Not Evaluated          NaN            NaN        NaN          NaN
# 16  Not Evaluated          NaN            NaN        NaN          NaN
# 17  Not Evaluated          NaN            NaN        NaN          NaN
# 18  Not Evaluated          NaN            NaN        NaN          NaN
# 19  Not Evaluated          NaN            NaN        NaN          NaN
#
#    vertebrae  \
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6        NaN
# 7        NaN
# 8        NaN
# 9        NaN
# 10       NaN
# 11       NaN
# 12       NaN
# 13       NaN
# 14       NaN
# 15       NaN
# 16       NaN
# 17       NaN
# 18       NaN
# 19       NaN
#
#                                                                                        shortDescription  \
# 0   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 1   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 2   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 3   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 4   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 5   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 6   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 7   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 8   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 9   Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 10  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 11  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 12  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 13  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 14  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 15  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 16  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 17  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 18  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
# 19  Body up to 13 cm long; with 4 flying buttresses, joining the basal corners of the oral aboral po...
#
#    threatToHumans preferredTemperatureMin preferredTemperatureMean  \
# 0             NaN                     3.3                     12.3
# 1             NaN                     3.3                     12.3
# 2             NaN                     3.3                     12.3
# 3             NaN                     3.3                     12.3
# 4             NaN                     3.3                     12.3
# 5             NaN                     3.3                     12.3
# 6             NaN                     3.3                     12.3
# 7             NaN                     3.3                     12.3
# 8             NaN                     3.3                     12.3
# 9             NaN                     3.3                     12.3
# 10            NaN                     3.3                     12.3
# 11            NaN                     3.3                     12.3
# 12            NaN                     3.3                     12.3
# 13            NaN                     3.3                     12.3
# 14            NaN                     3.3                     12.3
# 15            NaN                     3.3                     12.3
# 16            NaN                     3.3                     12.3
# 17            NaN                     3.3                     12.3
# 18            NaN                     3.3                     12.3
# 19            NaN                     3.3                     12.3
#
#    preferredTemperatureMax cellsBasedOn phylogeneticDiversity  \
# 0                     21.7         1171                   NaN
# 1                     21.7         1171                   NaN
# 2                     21.7         1171                   NaN
# 3                     21.7         1171                   NaN
# 4                     21.7         1171                   NaN
# 5                     21.7         1171                   NaN
# 6                     21.7         1171                   NaN
# 7                     21.7         1171                   NaN
# 8                     21.7         1171                   NaN
# 9                     21.7         1171                   NaN
# 10                    21.7         1171                   NaN
# 11                    21.7         1171                   NaN
# 12                    21.7         1171                   NaN
# 13                    21.7         1171                   NaN
# 14                    21.7         1171                   NaN
# 15                    21.7         1171                   NaN
# 16                    21.7         1171                   NaN
# 17                    21.7         1171                   NaN
# 18                    21.7         1171                   NaN
# 19                    21.7         1171                   NaN
#
#    bayesianLengthWeightA bayesianLengthWeightB resilience priorR sdRange  \
# 0                    NaN                   NaN        NaN    NaN     NaN
# 1                    NaN                   NaN        NaN    NaN     NaN
# 2                    NaN                   NaN        NaN    NaN     NaN
# 3                    NaN                   NaN        NaN    NaN     NaN
# 4                    NaN                   NaN        NaN    NaN     NaN
# 5                    NaN                   NaN        NaN    NaN     NaN
# 6                    NaN                   NaN        NaN    NaN     NaN
# 7                    NaN                   NaN        NaN    NaN     NaN
# 8                    NaN                   NaN        NaN    NaN     NaN
# 9                    NaN                   NaN        NaN    NaN     NaN
# 10                   NaN                   NaN        NaN    NaN     NaN
# 11                   NaN                   NaN        NaN    NaN     NaN
# 12                   NaN                   NaN        NaN    NaN     NaN
# 13                   NaN                   NaN        NaN    NaN     NaN
# 14                   NaN                   NaN        NaN    NaN     NaN
# 15                   NaN                   NaN        NaN    NaN     NaN
# 16                   NaN                   NaN        NaN    NaN     NaN
# 17                   NaN                   NaN        NaN    NaN     NaN
# 18                   NaN                   NaN        NaN    NaN     NaN
# 19                   NaN                   NaN        NaN    NaN     NaN
#
#                     vulnerability priceCategory source
# 0   Low vulnerability (10 of 100)       Unknown     ca
# 1   Low vulnerability (10 of 100)       Unknown     ca
# 2   Low vulnerability (10 of 100)       Unknown     ca
# 3   Low vulnerability (10 of 100)       Unknown     ca
# 4   Low vulnerability (10 of 100)       Unknown     ca
# 5   Low vulnerability (10 of 100)       Unknown     ca
# 6   Low vulnerability (10 of 100)       Unknown     ca
# 7   Low vulnerability (10 of 100)       Unknown     ca
# 8   Low vulnerability (10 of 100)       Unknown     ca
# 9   Low vulnerability (10 of 100)       Unknown     ca
# 10  Low vulnerability (10 of 100)       Unknown     ca
# 11  Low vulnerability (10 of 100)       Unknown     ca
# 12  Low vulnerability (10 of 100)       Unknown     ca
# 13  Low vulnerability (10 of 100)       Unknown     ca
# 14  Low vulnerability (10 of 100)       Unknown     ca
# 15  Low vulnerability (10 of 100)       Unknown     ca
# 16  Low vulnerability (10 of 100)       Unknown     ca
# 17  Low vulnerability (10 of 100)       Unknown     ca
# 18  Low vulnerability (10 of 100)       Unknown     ca
# 19  Low vulnerability (10 of 100)       Unknown     ca

# %%
dataset['depthRange'] = dataset['depthRange'].str.replace(' - ','--')
dataset['usualRange'] = dataset['usualRange'].str.replace(' - ','--')
dataset['distributionRangeCoordinates'] = dataset['distributionRangeCoordinates'].str.replace(' - ','--')
dataset['sizeRange'] = dataset['sizeRange'].str.replace(' - ','--')
dataset['dorsalSpines'] = dataset['dorsalSpines'].str.replace(' - ','--')
dataset['dorsalSoftRays'] = dataset['dorsalSoftRays'].str.replace('-','--')
dataset['analSoftRays'] = dataset['analSoftRays'].str.replace(' - ','--')
dataset['vertebrae'] = dataset['vertebrae'].str.replace(' - ','--')
dataset['sdRange'] = dataset['sdRange'].str.replace(' - ','--')

dataset['maxLength'] = pd.to_numeric(dataset['maxLength'])
dataset['maxWeight'] = pd.to_numeric(dataset['maxWeight'])
dataset['maxAge'] = pd.to_numeric(dataset['maxAge'])
dataset['preferredTemperatureMin'] = pd.to_numeric(dataset['preferredTemperatureMin'])
dataset['preferredTemperatureMean'] = pd.to_numeric(dataset['preferredTemperatureMean'])
dataset['preferredTemperatureMax'] = pd.to_numeric(dataset['preferredTemperatureMax'])
dataset['cellsBasedOn'] = pd.to_numeric(dataset['cellsBasedOn'])
dataset['phylogeneticDiversity'] = pd.to_numeric(dataset['phylogeneticDiversity'])
dataset['bayesianLengthWeightA'] = pd.to_numeric(dataset['bayesianLengthWeightA'])
dataset['bayesianLengthWeightB'] = pd.to_numeric(dataset['bayesianLengthWeightB'])
dataset['priorR'] = pd.to_numeric(dataset['priorR'])

dataset.to_csv('speciesDataset2.csv')

# %%
dataset.to_csv('speciesDataset2.csv')
